# %%
# Import Dependencies
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup
import time

# %%
# Read CSV File
author_df = pd.read_csv("tables/author_table.csv")
author_df

# %%
# Make list of authors
author_list = author_df['main author'].tolist()
author_list1 = author_list[:10000]

# %%
# Length of authors list
len(author_list)

# %%
# Base url
base_url = "https://en.wikipedia.org/wiki/"
# create url along with author name
author_name = "J.K. Rowling"
url = base_url + author_name
print(url)

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())

# %%
soup.find('span' , class_="bday").text

# %%
# Extract title text
title = soup.title.text
print(title)

# %%
list1=['Suzanne Collins',
 'J.K. Rowling',
 'Stephenie Meyer',
 'Markus Zusak ',
 'George Orwell']

# %%
 # Base url
base_url = "https://en.wikipedia.org/wiki/"
author_dict = {}
for author_name in author_list1:
    # create url along with author name
    url = base_url + author_name
    # Retrieve page with the requests module
    response = requests.get(url)
    try:
    # Create BeautifulSoup object; parse with 'html.parser'
        soup = BeautifulSoup(response.text, 'html.parser')
        author_dict[author_name]= soup.find('span', class_="bday").text
    except AttributeError:
        author_dict[author_name]= "none"

   
   
author_dict
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7q/sxlhn3n95sqgl8ql5btb2t_w0000gn/T/ipykernel_7858/1194535510.py in <module>
#       6    url = base_url + author_name
#       7    # Retrieve page with the requests module
# ----> 8    response = requests.get(url)
#       9    try:
#      10    # Create BeautifulSoup object; parse with 'html.parser'
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     decode_content=False,
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#     452
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1038         # Force connect early to allow us to validate the connection.
#    1039         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040             conn.connect()
#    1041
#    1042         if not conn.is_verified:
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     356     def connect(self):
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#     360         tls_in_tls = False
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#     177
#
# ~/opt/anaconda3/envs/PythonDataOne/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:

# %%
author_dict
# Out:
# {'Suzanne Collins': '1962-08-10',
#  'J.K. Rowling': '1965-07-31',
#  'Stephenie Meyer': '1973-12-24',
#  'Markus Zusak ': '1975-06-23',
#  'George Orwell': 'none',
#  'J.R.R. Tolkien': '1892-01-03',
#  'Margaret Mitchell': '1900-11-08',
#  'Shel Silverstein': '1930-09-25',
#  'Emily Brontë': '1818-07-30',
#  'Arthur Golden': '1956-12-06',
#  'Lewis Carroll': '1832-01-27',
#  'Charlotte Brontë': '1816-04-21',
#  'Ray Bradbury': '1920-08-22',
#  'Veronica Roth ': '1988-08-19',
#  'William Golding': '1911-09-19',
#  'William Shakespeare': '2008-04-11',
#  'Paulo Coelho ': '1947-08-24',
#  'Fyodor Dostoyevsky': '1821-11-11',
#  'Cassandra Clare ': '1973-07-27',
#  'Orson Scott Card': '1951-08-24',
#  'L.M. Montgomery': '1874-11-30',
#  'E.B. White': 'none',
#  'John Steinbeck': 'none',
#  'Audrey Niffenegger ': '1963-06-13',
#  'Bram Stoker': '1847-11-08',
#  'Aldous Huxley': '1894-07-26',
#  'J.D. Salinger': '1919-01-01',
#  'William Goldman': '1931-08-12',
#  'Rick Riordan ': '1964-06-05',
#  'Frances Hodgson Burnett': '1849-11-24',
#  'Khaled Hosseini ': '1965-03-04',
#  "Madeleine L'Engle": '1918-11-29',
#  'George R.R. Martin': '1948-09-20',
#  'Mark Twain': '1835-11-30',
#  'Alice Sebold': '1963-09-06',
#  'Maurice Sendak': '1928-06-10',
#  'Dr. Seuss': '1904-03-02',
#  'Homer': 'none',
#  'Yann Martel': '1963-06-25',
#  'Charles Dickens': '1812-02-07',
#  'Sara Gruen ': 'none',
#  'Vladimir Nabokov': 'none',
#  'Kurt Vonnegut Jr.': '1922-11-11',
#  'Mary Wollstonecraft Shelley': '1797-08-30',
#  'Lois Lowry ': '1937-03-20',
#  'Joseph Heller': '1923-05-01',
#  'Frank Herbert': '1920-10-08',
#  'Stephen King ': '1947-09-21',
#  'Richard Adams': '1920-05-09',
#  'Louisa May Alcott': '1832-11-29',
#  'Diana Gabaldon ': '1952-01-11',
#  'Jodi Picoult ': 'none',
#  'Roald Dahl': '1916-09-13',
#  'Daphne du Maurier': '1907-05-13',
#  'Alice Walker': '1944-02-09',
#  'Betty Smith': '1896-12-15',
#  'Anthony Burgess': '1917-02-25',
#  'Cormac McCarthy': '1933-07-20',
#  'Frank McCourt': '1930-08-19',
#  'Richelle Mead ': '1976-11-12',
#  'Barbara Kingsolver': '1955-04-08',
#  'Philip Pullman': '1946-10-19',
#  'Miguel de Cervantes Saavedra': 'none',
#  'Ayn Rand': '1905-02-02',
#  'Ernest Hemingway': '1899-07-21',
#  'Nicholas Sparks ': '1965-12-31',
#  'A.A. Milne': '1882-01-18',
#  'Edgar Allan Poe': '1809-01-19',
#  'Anne Rice': '1941-10-04',
#  'John Irving ': '1942-03-02',
#  'Herman Melville': '1819-08-01',
#  'Anita Diamant ': '1951-06-27',
#  'Sue Monk Kidd ': '1948-08-12',
#  'Agatha Christie': '1890-09-15',
#  'Jeffrey Eugenides': '1960-03-08',
#  'Mikhail Bulgakov': 'none',
#  'Patrick Rothfuss ': '1973-06-06',
#  'Christopher Paolini ': '1983-11-17',
#  'Jack Kerouac': '1922-03-12',
#  'Mark Haddon': '1962-10-28',
#  'Eric Carle': '1929-06-25',
#  'Mitch Albom ': '1958-05-23',
#  'Milan Kundera': '1929-04-01',
#  'Umberto Eco': '1932-01-05',
#  'Wilson Rawls': '1913-09-24',
#  'Nathaniel Hawthorne': '1804-07-04',
#  'Truman Capote': '1924-09-30',
#  'Chuck Palahniuk ': '1962-02-21',
#  'Becca Fitzpatrick ': '1979-02-03',
#  'Alexandre Dumas': '1802-07-24',
#  'Larry McMurtry': '1936-06-03',
#  'Patrick Süskind': '1949-03-26',
#  'Louis Sachar ': '1954-03-20',
#  'Alan Moore ': '1953-11-18',
#  'Laura Ingalls Wilder': '1867-02-07',
#  'Dante Alighieri': 'none',
#  'J.M. Barrie': '1860-05-09',
#  'Erich Maria Remarque': '1898-06-22',
#  'Reduced Shakespeare Company': 'none',
#  'Gabriel García Márquez': '1927-03-06',
#  'Douglas Adams': '1952-03-11',
#  'Ian McEwan': '1948-06-21',
#  'Oscar Wilde': '1854-10-16',
#  'Elizabeth Gilbert ': '1969-07-18',
#  'Zora Neale Hurston': '1891-01-07',
#  'L. Frank Baum': '1856-05-15',
#  'Margaret Wise Brown': 'none',
#  'Pearl S. Buck': '1892-06-26',
#  'Joseph Conrad': '1857-12-03',
#  'Kahlil Gibran': '1883-01-06',
#  'Marion Zimmer Bradley': '1930-06-03',
#  'Amy Tan ': '1952-02-19',
#  'Jane Carruth ': 'none',
#  'Jack London': '1876-01-12',
#  'Richard Bach ': '1936-06-23',
#  'Norton Juster': '1929-06-02',
#  'Katherine Paterson': '1932-10-31',
#  'Stieg Larsson': '1954-08-15',
#  'James Dashner ': '1972-11-26',
#  'Michael Ende': '1929-11-12',
#  'Robert Louis Stevenson': '1850-11-13',
#  'E.L. James ': '1963-03-07',
#  'Jean M. Auel': '1936-02-18',
#  'Geoffrey Chaucer': 'none',
#  'Gregory Maguire': '1954-06-09',
#  'James Clavell': '1921-10-10',
#  'Jonathan Safran Foer ': '1977-02-21',
#  'Thomas Keneally': '1935-10-07',
#  'Michael Crichton': '1942-10-23',
#  'Erin Morgenstern ': '1978-07-08',
#  'Lauren Kate ': '1981-03-21',
#  'Ki Longfellow ': '1944-12-09',
#  'Toni Morrison': '1931-02-18',
#  'John Kennedy Toole': '1937-12-17',
#  'Kiera Cass ': '1981-05-19',
#  'Margery Williams Bianco': 'none',
#  'Arthur Miller': '1915-10-17',
#  'Arundhati Roy ': '1961-11-24',
#  'Kenneth Grahame': '1859-03-08',
#  'Tracy Chevalier ': '1962-10-19',
#  'Corrie ten Boom': 'none',
#  'Thomas Harris': 'none',
#  'Maggie Stiefvater ': '1981-11-18',
#  'Scott Westerfeld ': '1963-05-06',
#  'Viktor E. Frankl': '1905-03-26',
#  'Wally Lamb ': '1950-10-17',
#  'Gaston Leroux': '1868-05-06',
#  'John Grogan': '1957-03-20',
#  'Gail Carson Levine ': '1947-09-17',
#  'Haruki Murakami': '1949-01-12',
#  'José Saramago': '1922-11-16',
#  'William Paul Young': '1955-05-11',
#  'P.C. Cast ': '1960-04-30',
#  'Mary Ann Shaffer': 'none',
#  'Hunter S. Thompson': '1937-07-18',
#  'Isabel Allende ': '1942-08-02',
#  'Bill Watterson': '1958-07-05',
#  'Alex Haley': '1921-08-11',
#  'Diana Wynne Jones': '1934-08-16',
#  'Robert A. Heinlein': '1907-07-07',
#  "Scott O'Dell": 'none',
#  'Donna Tartt': '1963-12-23',
#  'Janet Fitch ': '1955-11-09',
#  'Lauren Oliver ': '1982-11-08',
#  'Jamie McGuire ': '1983-11-13',
#  'John Green ': '1977-08-24',
#  'Laurie Halse Anderson ': '1961-10-23',
#  'T.H. White': '1906-05-29',
#  'Neil Gaiman ': '1960-11-10',
#  'Jon Krakauer ': '1954-04-12',
#  'Cornelia Funke ': '1958-12-10',
#  'Christopher Moore ': 'none',
#  'Elizabeth Kostova': '1964-12-26',
#  'Arthur Conan Doyle': '1859-05-22',
#  'Voltaire': '1694-11-21',
#  'Tim Butcher ': '1967-11-15',
#  'John Milton': '1608-12-09',
#  'James Herriot': '1916-10-03',
#  'Diane Setterfield ': '1964-08-22',
#  'Isaac Asimov': 'none',
#  "Tim O'Brien": 'none',
#  'Johanna Spyri': '1827-06-12',
#  'Judy Blume ': '1938-02-12',
#  'Jostein Gaarder': '1952-08-08',
#  'Kate Chopin': '1850-02-08',
#  'Rainbow Rowell ': '1973-02-24',
#  'William Styron': '1925-06-11',
#  'Pat Conroy': '1945-10-26',
#  'Kazuo Ishiguro': '1954-11-08',
#  'Charlaine Harris ': '1951-11-25',
#  'Fannie Flagg': '1944-09-21',
#  'Ernest Cline ': '1972-03-29',
#  'George Eliot': '1819-11-22',
#  'Jon Stone': '1932-04-13',
#  'Sarah J. Maas ': '1986-03-05',
#  'Helen Fielding ': '1958-02-19',
#  'Virginia Woolf': '1882-01-25',
#  'Bryce Courtenay': '1933-08-14',
#  'C.S. Lewis': '1898-11-29',
#  'Philip K. Dick': '1928-12-16',
#  'Bill Bryson': '1951-12-08',
#  'Jojo Moyes ': '1969-08-04',
#  'Garth Stein ': 'none',
#  'Brandon Sanderson ': '1975-12-19',
#  'Gayle Forman ': '1970-06-05',
#  'Anna Sewell': '1820-03-30',
#  'James Joyce': 'none',
#  'Jonathan Swift': '1667-11-30',
#  'Ann Patchett': '1963-12-02',
#  'Bret Easton Ellis': '1964-03-07',
#  'Robert Munsch': '1945-06-11',
#  'Jane Austen': '1775-12-16',
#  'Charles Frazier': '1950-11-04',
#  'Unknown': 'none',
#  'Natalie Babbitt': '1932-07-18',
#  'Kami Garcia ': '1972-03-25',
#  'Hermann Hesse': '1877-07-02',
#  'J.R. Ward ': 'none',
#  'Beatrice Sparks ': '1917-01-15',
#  'Robert Jordan': '1948-10-17',
#  'William Faulkner': '1897-09-25',
#  'John Knowles': '1926-09-16',
#  'Art Spiegelman': '1948-02-15',
#  'Michael Chabon': '1963-05-24',
#  'Dave Pelzer ': '1960-12-29',
#  'Jerry Spinelli': '1941-02-01',
#  'Lao Tzu': 'none',
#  'Salman Rushdie': '1947-06-19',
#  'Michael Ondaatje': '1943-09-12',
#  'David Mitchell': 'none',
#  'Robert M. Pirsig': '1928-09-06',
#  'Andy Weir ': '1972-06-16',
#  'John Grisham ': '1955-02-08',
#  'Willa Cather': '1873-12-07',
#  'Tahereh Mafi': '1988-11-09',
#  'Boris Pasternak': 'none',
#  'Victor Hugo': '1802-02-26',
#  'Laura Esquivel': '1950-09-30',
#  'Emma Donoghue ': '1969-10-24',
#  'Leigh Bardugo ': '1975-04-06',
#  'Charles Darwin': '1809-02-12',
#  'Rohinton Mistry': 'none',
#  'Laini Taylor ': '1971-12-11',
#  'Alyson Noel ': '1965-12-03',
#  'John Berendt': '1939-12-05',
#  'Tennessee Williams': '1911-03-26',
#  'David Foster Wallace': '1962-02-21',
#  'Niccolò Machiavelli': 'none',
#  'Johann Wolfgang von Goethe': '1749-08-28',
#  'Lisa See ': '1955-02-18',
#  'Stephanie Perkins ': 'none',
#  'James Patterson ': '1947-03-22',
#  'Ally Condie ': '1978-11-02',
#  'V.C. Andrews': '1923-06-06',
#  'Annie Proulx': '1935-08-22',
#  'Laura Hillenbrand': '1967-05-15',
#  'Emmuska Orczy': '1865-09-23',
#  'Chaim Potok': '1929-02-17',
#  'Nick Hornby': '1957-04-17',
#  'Anthony Doerr ': '1973-10-27',
#  'Eoin Colfer': '1965-05-14',
#  'Astrid Lindgren': '1907-11-14',
#  'Bernhard Schlink': '1944-07-06',
#  'Gregory David Roberts': '1952',
#  'Erik Larson ': 'none',
#  'Francine Rivers ': 'none',
#  'Edith Wharton': '1862-01-24',
#  'Dan Brown ': '1964-06-22',
#  'William Gibson': '1948-03-17',
#  'Rebecca Wells ': 'none',
#  'T.S. Eliot': '1888-09-26',
#  'Maya Angelou': '1928-04-04',
#  'Upton Sinclair': '1878-09-20',
#  'David Guterson': '1956-05-04',
#  'Robert Graves': '1895-07-24',
#  'David Sedaris': '1956-12-26',
#  'E.M. Forster': '1879-01-01',
#  'Plato': 'none',
#  'William Peter Blatty': '1928-01-07',
#  'R.D. Ronald': 'none',
#  'Rick Yancey': '1962-11-04',
#  'Julie Kagawa ': '1982-10-12',
#  'Kyle Keyes': 'none',
#  'Benjamin Alire Sáenz ': '1954-08-16',
#  'Anonymous': 'none',
#  'William Makepeace Thackeray': '1811-07-18',
#  'Terry Goodkind': '1948-01-11',
#  'Elizabeth Gaskell': '1810-09-29',
#  'Evelyn Waugh': '1903-10-28',
#  'Richard Dawkins ': '1941-03-26',
#  'W. Somerset Maugham': '1874-01-25',
#  'Neal Stephenson ': '1959-10-31',
#  'Max Brooks ': '1972-05-22',
#  'Libba Bray ': '1964-03-11',
#  'Sylvia Day ': '1973-03-11',
#  'H.G. Wells': '1866-09-21',
#  'Kelley Armstrong ': '1968-12-14',
#  'Alan Paton': '1903-01-11',
#  'Dalton Trumbo': '1905-12-09',
#  'Joanne Harris ': '1964-07-03',
#  'Jeaniene Frost ': '1974-06-13',
#  'Greg Mortenson ': 'none',
#  'Simone Elkeles ': '1970-04-24',
#  'Victoria Aveyard ': '1990-07-27',
#  'Wilkie Collins': '1824-01-08',
#  'Sarah Dessen ': '1970-06-06',
#  'Arthur C. Clarke': '1917-12-16',
#  'Deborah Harkness ': 'none',
#  'Neal Shusterman ': '1962-11-12',
#  'Irvine Welsh': '1958-09-27',
#  'P.D. Eastman': '1909-11-25',
#  'Marcel Proust': '1871-07-10',
#  'Tatiana de Rosnay ': '1961-09-28',
#  'Chris Van Allsburg': '1949-06-18',
#  'Sherrilyn Kenyon ': '1965-12-11',
#  'D.H. Lawrence': '1885-09-11',
#  'Daniel Quinn': '1935-10-11',
#  'Michelle Hodkin ': 'none',
#  'Jennifer Niven ': 'none',
#  'Thomas Hardy': '1840-06-02',
#  'Pittacus Lore': 'none',
#  'Susan Ee ': 'none',
#  'Paullina Simons': 'none',
#  'Max Lucado ': '1955-01-11',
#  'Garth Nix ': '1963-07-19',
#  'Abraham Verghese ': '1955-05-30',
#  'Martin Heidegger': 'none',
#  'Shannon Hale ': '1974-01-26',
#  'Dodie Smith': '1896-05-03',
#  'Randy Pausch': '1960-10-23',
#  'Alexandra Bracken ': 'none',
#  'Michael Cunningham ': '1952-11-06',
#  'Melissa Marr ': '1972-07-25',
#  'Cecelia Ahern': '1981-09-30',
#  'Peter S. Beagle ': '1939-04-20',
#  'Dan Simmons': '1948-04-04',
#  'Lemony Snicket ': 'none',
#  'Edmond Rostand': '1868-04-01',
#  'Ellen Raskin': '1928-03-13',
#  'Jhumpa Lahiri': '1967-07-11',
#  'Robert Penn Warren': '1905-04-24',
#  'Diamante Lavendar ': 'none',
#  'W. Bruce Cameron ': '1956-07-25',
#  'Leif Enger': 'none',
#  'Lionel Shriver ': '1957-05-18',
#  'Patrick Ness': '1971-10-17',
#  'Iain Banks': 'none',
#  'Sun Tzu': 'none',
#  'Maria V. Snyder ': '1973-04-15',
#  'Edith Hamilton': '1867-08-12',
#  'Aleksandr Solzhenitsyn': '1918-12-11',
#  'Tim LaHaye': '1926-04-27',
#  'Jasper Fforde ': '1961-01-11',
#  'Kim Edwards ': '1958-05-04',
#  'Karen Marie Moning ': 'none',
#  'Michael Grant ': 'none',
#  'Richard Wright': 'none',
#  'Michael Shaara': 'none',
#  'Nicole Krauss': '1974-08-18',
#  'Italo Calvino': '1923-10-15',
#  'Robert Ludlum': '1927-05-25',
#  'A.S. Byatt': '1936-08-24',
#  'Thomas Pynchon': '1937-05-08',
#  'Howard Zinn': '1922-08-24',
#  'Richard Matheson': '1926-02-20',
#  'Stephen Hawking': '1942-01-08',
#  'Sophocles': 'none',
#  'Marissa Meyer ': '1984-02-19',
#  'Tamora Pierce ': '1954-12-13',
#  'David McCullough': '1933-07-07',
#  'Janet Evanovich ': '1943-04-22',
#  'Ursula K. Le Guin': '1929-10-21',
#  'Madeline Miller ': '1978-07-24',
#  'Marie Lu ': '1984-07-11',
#  'Shirley Jackson': '1916-12-14',
#  'Robin Hobb ': '1952-03-05',
#  'Jandy Nelson ': '1965-11-25',
#  'Clement C. Moore': '1779-07-15',
#  'Charlotte Perkins Gilman': '1860-07-03',
#  'John Fowles': '1926-03-31',
#  'Margaret Atwood ': '1939-11-18',
#  'Terry Pratchett': '1948-04-28',
#  'Dave Eggers': '1970-03-12',
#  'Scott Lynch ': '1978-04-02',
#  'Tom Robbins': '1932-07-22',
#  'Henri Charrière': '1906-11-16',
#  'Louis de Bernières': '1954-12-08',
#  'Ally Carter ': '1974-01-01',
#  'Thomas Mann': '1875-06-06',
#  'Ann Brashares': 'none',
#  'E.L. Konigsburg': '1930-02-10',
#  'Muriel Barbery': 'none',
#  'Carl Sagan': '1934-11-09',
#  'Raymond Chandler': '1888-07-23',
#  'Dee Brown': 'none',
#  'Joseph Campbell': '1904-03-26',
#  'Alexander McCall Smith ': '1948-08-24',
#  'Erich Segal': '1937-06-16',
#  'Rachel Caine ': '1962-04-27',
#  'Jules Verne': '1828-02-08',
#  'Sophie Kinsella ': '1970-12-12',
#  'Dean Koontz ': '1945-07-09',
#  'J.A. Redmerski ': 'none',
#  'Walter Scott': 'none',
#  'Steven D. Levitt': '1967-05-29',
#  'Kristin Hannah ': '1960-09-25',
#  'Virgil': 'none',
#  'Sharon Creech': '1945-07-29',
#  'Wallace Stegner': '1909-02-18',
#  'Rosamunde Pilcher': '1924-09-22',
#  'Jonathan Franzen': '1959-08-17',
#  'Michael Pollan ': '1955-02-06',
#  'Walter M. Miller Jr.': '1923-01-23',
#  'Rudyard Kipling': '1865-12-30',
#  'Jorge Luis Borges': '1899-08-24',
#  'David Nicholls': 'none',
#  'Helen Keller': '1880-06-27',
#  'Katherine Dunn': '1945-10-24',
#  'Henry James': '1843-04-15',
#  'Kate DiCamillo ': '1964-03-25',
#  'Pierce Brown ': '1988-01-28',
#  'Paula Hawkins ': 'none',
#  'Ned Vizzini': '1981-04-04',
#  'Kristin Cashore': 'none',
#  'Steve Snyder ': 'none',
#  'Lisa Genova ': '1970-11-22',
#  'Koushun Takami': '1969-01-10',
#  'P.L. Travers': '1899-08-09',
#  'Anne Morrow Lindbergh': '1906-06-22',
#  'Richard Yates': 'none',
#  'Brian Selznick': '1966-07-14',
#  'F. Scott Fitzgerald': '1896-09-24',
#  'Olive Ann Burns': 'none',
#  'Jean-Paul Sartre': '1905-06-21',
#  'Justin Cronin ': 'none',
#  'Robert Frost': '1874-03-26',
#  'Leon Uris': '1924-08-03',
#  'Stephen R. Covey': '1932-10-24',
#  'Andrew Davidson ': 'none',
#  'Winston Groom': '1943-03-23',
#  'Mary Doria Russell ': '1950-08-19',
#  'Angie Thomas ': '1988-09-20',
#  'Sylvain Reynard ': 'none',
#  'Kate Morton ': 'none',
#  'Robert James Waller': '1939-08-01',
#  'Jeffrey Archer': '1940-04-15',
#  'Dennis Lehane ': '1965-08-04',
#  'James Frey': '1969-09-12',
#  'Laurell K. Hamilton ': '1963-02-19',
#  'Jeanne DuPrau': '1944-06-09',
#  'Jeannette Walls': '1960-04-21',
#  'Becky Albertalli ': '1982-11-17',
#  'Catherine Marshall': '1914-09-27',
#  'Jonathan Stroud ': '1970-10-27',
#  'Ellen Hopkins ': '1955-03-26',
#  'Mark Z. Danielewski ': '1966-03-05',
#  'Tom Clancy': '1947-04-12',
#  'Hubert SelJr.': 'none',
#  'Irving Stone': 'none',
#  'David Wroblewski': 'none',
#  'Charles Bukowski': '1920-08-16',
#  'Robin McKinley': '1952-11-16',
#  'Billie Letts': '1938-05-30',
#  'William S. Burroughs': '1914-02-05',
#  'Albert Camus': '1913-11-07',
#  'L.J. Smith ': '1980-05-13',
#  'Louis-Ferdinand Céline': '1894-05-27',
#  'Nevil Shute': '1899-01-17',
#  'S.C. Stephens ': 'none',
#  'Richard Bachman ': 'none',
#  'Brandon Mull ': '1974-11-08',
#  'Ken Kesey': '1935-09-17',
#  'Tammara Webber ': 'none',
#  'Yevgeny Zamyatin': '1884-02-01',
#  'Mildred D. Taylor': '1943-09-13',
#  'Colleen Hoover ': '1979-12-11',
#  'Gary Chapman': 'none',
#  'Marcus Aurelius': '121-04-26',
#  'J.M. Coetzee': '1940-02-09',
#  'Aprilynne Pike': 'none',
#  'Junot Díaz': '1968-12-31',
#  'Gillian Flynn ': '1971-02-24',
#  'Samuel Taylor Coleridge': '1772-10-21',
#  'Krishna-Dwaipayana Vyasa': 'none',
#  'Nancy E. Turner': 'none',
#  'David Levithan ': '1972-09-07',
#  'Nicholas Evans': '1950-07-26',
#  'Dashiell Hammett': '1894-05-27',
#  'Robert Musil': '1880-11-06',
#  'Colleen Houck ': 'none',
#  'Brian Jacques': '1939-06-15',
#  'Erin Hunter': 'none',
#  'John Flanagan': 'none',
#  'André Aciman ': '1951-01-02',
#  'Rachel Hawkins ': '1992-01-31',
#  'Cynthia Hand ': 'none',
#  'Don DeLillo': '1936-11-20',
#  'Munro Leaf': 'none',
#  'Kim Harrison ': 'none',
#  'Alex Flinn ': '1966-10-23',
#  'M.M. Kaye': '1908-08-21',
#  'Aimee Cabo Nikolov ': 'none',
#  'Melissa de la Cruz ': '1971-09-07',
#  'Henrik Ibsen': '1828-03-20',
#  'Peter Høeg': '1957-05-17',
#  'Lauren Weisberger': '1977-03-28',
#  'Hanya Yanagihara ': 'none',
#  'William Blake': '1757-11-28',
#  'Augusten Burroughs ': '1965-10-23',
#  'Tabitha Suzuma ': '1975-02-02',
#  'James Fenimore Cooper': '1789-09-15',
#  'Beth Revis ': 'none',
#  'Gary Paulsen': '1939-05-17',
#  'Sebastian Faulks': '1953-04-20',
#  'Douglas R. Hofstadter': '1945-02-15',
#  'John Ajvide Lindqvist': '1968-12-02',
#  'Andrea Cremer ': 'none',
#  'Jim Butcher ': '1971-10-26',
#  'Jacqueline Susann': '1918-08-20',
#  'Alexander Pushkin': '1799-06-06',
#  'Claudia Gray ': 'none',
#  'Ruta Sepetys ': '1967-11-19',
#  'Raymond E. Feist': '1945-12-21',
#  'Sarah Waters': '1966-07-21',
#  'Patricia Briggs': 'none',
#  'Robert R. McCammon': 'none',
#  'Vincent Bugliosi': '1934-08-18',
#  'Herman Wouk': '1915-05-27',
#  'Norman Maclean': '1902-12-23',
#  'Jon Scieszka': '1954-09-08',
#  'Trenton Lee Stewart ': '1970-05-27',
#  'Pablo Neruda': '1904-07-12',
#  'H.P. Lovecraft': '1890-08-20',
#  'V.E. Schwab': '1987-07-07',
#  'Nicola Yoon ': 'none',
#  'Frank E. Peretti': '1951-01-13',
#  'Alice Hoffman ': '1952-03-16',
#  'Henry Miller': '1891-12-26',
#  'Sherman Alexie': '1966-10-07',
#  'Brent Weeks ': '1977-03-07',
#  'Günter Grass': '1927-10-16',
#  'Jennifer L. Armentrout ': '1980-06-11',
#  'Ann-Marie MacDonald': '1958-10-29',
#  'Rebecca Skloot ': '1972-09-19',
#  'Mia Sheridan ': 'none',
#  'Amanda Hocking ': '1984-07-12',
#  'Jacqueline Carey ': '1964-10-09',
#  'Ursula Hegi': 'none',
#  'Marjane Satrapi': '1969-11-22',
#  'Nikos Kazantzakis': '1883-03-02',
#  'Peter Benchley': '1940-05-08',
#  'Kathleen Zamboni McCormick ': 'none',
#  'Josephine Angelini ': 'none',
#  'Malcolm Gladwell': '1963-09-03',
#  'Giovanni Boccaccio': 'none',
#  'James McBride ': 'none',
#  'S.J. Watson ': 'none',
#  'Émile Zola': '1840-04-02',
#  'Murasaki Shikibu': 'none',
#  'Richard Russo ': '1949-07-15',
#  'Abbi Glines ': '1977-04-16',
#  'Laurie R. King ': '1952-09-19',
#  'Graham Greene': '1904-10-02',
#  'Geraldine Brooks ': 'none',
#  'Louise Fitzhugh': '1928-10-05',
#  'Anne Tyler ': '1941-10-25',
#  'Stephen Crane': '1871-11-01',
#  'Kenneth Jarrett Singleton': 'none',
#  'John Wyndham': '1903-07-10',
#  'Joe Abercrombie': '1974-12-31',
#  'Frank Miller': '1957-01-27',
#  'Melina Marchetta ': '1965-03-25',
#  'Julio Cortázar': '1914-08-26',
#  'Stendhal': '1783-01-23',
#  'Sara Shepard ': '1977-04-08',
#  'Veronica Rossi ': '1973-06-16',
#  'Fernando Pessoa': '1888-06-13',
#  'John Williams': '1932-02-08',
#  'James A. Michener': '1907-02-03',
#  'Mervyn Peake': '1911-07-09',
#  'Dorothy Allison': '1949-04-11',
#  'Michael Scott ': 'none',
#  'Alexandra Adornetto': 'none',
#  'Matthew Quick ': '1973-10-23',
#  'Wendy Higgins ': 'none',
#  'John le Carré': '1931-10-19',
#  'Charles Baudelaire': 'none',
#  'Marguerite Yourcenar': '1903-06-08',
#  'Zadie Smith': '1975-10-25',
#  'Carlos Ruiz Zafón': '1964-09-25',
#  'Sarah Addison Allen ': 'none',
#  'Meg Cabot ': '1967-02-01',
#  'Trevor Alan Foris ': 'none',
#  'Maria Nhambu ': 'none',
#  'Anne Brontë': '1820-01-17',
#  'Ovid': 'none',
#  'Judith Viorst': '1931-02-02',
#  'Eckhart Tolle': '1948-02-16',
#  'David Benioff': '1970-09-25',
#  'Lucy Christopher ': 'none',
#  'Ken Follett ': '1949-06-05',
#  'Fred Gipson': 'none',
#  'Henryk Sienkiewicz': '1846-05-05',
#  'Anne Willow ': 'none',
#  'Emily Giffin ': '1972-03-20',
#  'C.C. Hunter ': 'none',
#  'Fredrik Backman ': '1981-06-02',
#  'Marilynne Robinson': '1943-11-26',
#  'E.L. Doctorow': '1931-01-06',
#  'China Miéville ': '1972-09-06',
#  'Hans Christian Andersen': '1805-04-02',
#  'Laurence Sterne': '1713-11-24',
#  'Amie Kaufman ': 'none',
#  'Theodore Dreiser': '1871-08-27',
#  'Newt Scamander ': 'none',
#  'Nancy Farmer ': 'none',
#  'Arthur Koestler': '1905-09-05',
#  'John Howard Griffin': '1920-06-16',
#  'Frank B. Gilbreth Jr.': 'none',
#  'Laura Joffe Numeroff ': '1953-07-14',
#  'Jeff Kinney ': '1971-02-19',
#  'Aravind Adiga': '1974-10-23',
#  'Sharon M. Draper ': '1948-08-21',
#  'John Hersey': '1914-06-17',
#  'Jonas Jonasson': '1961-07-06',
#  'Margaret Peterson Haddix': '1964-04-09',
#  'Wilbur Smith': '1933-01-09',
#  'David Eddings': '1931-07-07',
#  'Ishmael Beah': '1980-11-23',
#  'Clive Barker ': '1952-10-05',
#  'Katie McGarry ': 'none',
#  'Muriel Spark': '1918-02-01',
#  'Peter V. Brett ': '1973-02-08',
#  'Rupi Kaur ': '1992-10-04',
#  'John Scalzi ': '1969-05-10',
#  'Carrie Jones ': 'none',
#  'Mary Stewart': 'none',
#  'Jenny Han ': 'none',
#  'Spencer Johnson': 'none',
#  'Joe Haldeman': '1943-06-09',
#  'Juan Gomez-Jurado ': '1977-12-16',
#  'Jerzy Kosiński': '1933-06-14',
#  "Flannery O'Connor": '1925-03-25',
#  'Sidney Sheldon': '1917-02-11',
#  'Katy Evans ': '1976-03-03',
#  'Ransom Riggs': '1979-02-03',
#  'Elizabeth Chandler': '1807-12-24',
#  'Delia Owens ': 'none',
#  'Terry Brooks ': '1944-01-08',
#  'Heath Sommer ': 'none',
#  'Lee Child ': '1954-10-29',
#  'Knut Hamsun': '1859-08-04',
#  "Flann O'Brien": '1911-10-05',
#  'Ivan Turgenev': '1818-11-09',
#  'Derek Landy': '1974-10-23',
#  'M. Robinson': 'none',
#  'Vikram Seth': '1952-06-20',
#  'Frederick Forsyth': '1938-08-25',
#  'Susan Cain ': '1968-03-20',
#  'Todd Burpo': 'none',
#  'Judi Barrett': 'none',
#  'Susanna Kaysen': '1948-11-11',
#  'Paul Auster': '1947-02-03',
#  'Hilary Mantel ': 'none',
#  'Wendelin Van Draanen ': 'none',
#  'Jennifer A. Nielsen ': '1971-07-10',
#  'Donna Woolfolk Cross ': 'none',
#  'Sena Jeter Naslund': 'none',
#  'Alfred Lansing': 'none',
#  'Malorie Blackman ': 'none',
#  'Harlan Coben ': 'none',
#  'Dalai Lama XIV': '1935-07-06',
#  'John Connolly ': 'none',
#  'Pierre Choderlos de Laclos': '1741-10-18',
#  'John Gardner': 'none',
#  'John Marsden': 'none',
#  'David James Duncan': 'none',
#  'Alice Clayton ': 'none',
#  'Afroz Alam ': 'none',
#  'Lawrence Hill': '1957-01-24',
#  'Nikolai Gogol': '1809-03-20',
#  'Kirsty Moseley ': 'none',
#  'Kennilworthy Whisp ': 'none',
#  'Leo Tolstoy': '1828-09-09',
#  'Ilona Andrews ': 'none',
#  'John Tiffany ': 'none',
#  'Robert Galbraith': 'none',
#  'Founding Fathers': 'none',
#  'Trudi Canavan': 'none',
#  'Amy Plum ': 'none',
#  'Tara Westover ': '1986-09-30',
#  'Michel Guyon ': 'none',
#  "Robert C. O'Brien": '1966-06-18',
#  'Liane Moriarty ': '1966-11-15',
#  'Roger Zelazny': '1937-05-13',
#  'Shannon Messenger ': 'none',
#  'C.J. Roberts ': 'March 20, 1989',
#  'Philip Roth': '1933-03-19',
#  'Flora Rheta Schreiber': 'none',
#  'M.L. Stedman ': 'none',
#  'Nalini Singh ': '1945-09-01',
#  'Alex Garland': '1970-05-26',
#  'Sharon Kay Penman ': 'none',
#  'Graeme Simsion ': 'none',
#  'Carson McCullers': '1917-02-19',
#  'Isaac Marion ': '1981-12-30',
#  'Lawrence Durrell': '1912-02-27',
#  'Ammar Habib ': '1967-10-25',
#  'John Jakes': '1932-03-31',
#  'Tracey Garvis Graves ': 'none',
#  'David Fishelson ': '1956-07-24',
#  'Juan Rulfo': 'none',
#  'Connie Willis': '1945-12-31',
#  'T. Rafael Cimino ': '1963-06-04',
#  'Nelson Mandela': '1918-07-18',
#  'Rohith S. Katbamna ': 'none',
#  'Cheryl Strayed ': '1968-09-17',
#  'Simon Okill ': 'none',
#  'Vanessa Diffenbaugh ': 'none',
#  'Chris Colfer': '1990-05-27',
#  'Kiersten White ': 'none',
#  'Rick Warren': '1954-01-28',
#  'Cinda Williams Chima ': 'none',
#  'Malala Yousafzai': '1997-07-12',
#  'W.B. Yeats': 'none',
#  'Katherine Neville': 'none',
#  'Jean-Dominique Bauby': '1952-04-23',
#  'Stephanie Garber ': 'none',
#  'Sophie Jordan ': 'none',
#  'Guy Gavriel Kay ': '1954-11-07',
#  'Roberto Bolaño': '1953-04-28',
#  'Jeffery Deaver ': '1950-05-06',
#  'Robert Shea': '1933-02-14',
#  'Gena Showalter ': 'none',
#  'Barbara W. Tuchman': '1912-01-30',
#  'Chimamanda Ngozi Adichie': '1977-09-15',
#  'Jason Latshaw ': 'none',
#  'Stephen E. Ambrose': '1936-01-10',
#  'Anne McCaffrey': '1926-04-01',
#  'Rachel Carson': '1907-05-27',
#  'Anya Seton': '1904-01-23',
#  'Kirsten Fullmer ': 'none',
#  'Euripides': 'none',
#  'Walter Isaacson ': '1952-05-20',
#  'Gail Carriger ': '1976-05-04',
#  'Kody Keplinger ': '1991-08-08',
#  'Gail Honeyman': 'none',
#  'Jenny Downham': 'none',
#  'Eric Schlosser': '1959-08-17',
#  'Andy Szpuk ': 'none',
#  'Octavia E. Butler': '1947-06-22',
#  'Paul Kalanithi': 'none',
#  'Lauren DeStefano ': '1984-10-13',
#  'Robert T. Kiyosaki': '1947-04-08',
#  'Isak Dinesen': 'none',
#  'Lynne Truss': '1955-05-31',
#  'Anne Bishop': 'none',
#  'Christina Lauren ': 'none',
#  'Ivo Andrić': '1892-10-09',
#  'James Baldwin': '1924-08-02',
#  'Gillian Dance ': 'none',
#  'Emily St. John Mandel ': 'none',
#  'Carrie Ryan ': 'none',
#  'John Gray': 'none',
#  'Friedrich Nietzsche': '1844-10-15',
#  'Lara Adrian ': 'none',
#  'Larry Niven': '1938-04-30',
#  'Naomi Novik ': '1973-04-30',
#  'Irène Némirovsky': '1903-02-11',
#  'Noah Gordon': 'none',
#  'Megan Whalen Turner ': '1965-11-21',
#  'Primo Levi': '1919-07-31',
#  'Lev Grossman ': '1969-06-26',
#  'Tsugumi Ohba': 'none',
#  "Eugene O'Neill": '1888-10-16',
#  'Edwin A. Abbott': '1838-12-20',
#  'Elizabeth Wein ': '1964-10-02',
#  'Chloe Neill ': '1975-05-17',
#  'Azar Nafisi ': '1948-12-01',
#  'Melodie Ramone ': 'none',
#  'J.G. Ballard': '1930-11-15',
#  'Karl Marx': '1818-05-05',
#  'Huntley Fitzpatrick ': 'none',
#  'Patricia MacLachlan': '1938-03-03',
#  'Michelle Magorian': '1947-11-06',
#  'Julian Barnes': '1946-01-19',
#  'Alan Brennert ': '1954-05-30',
#  'Colum McCann ': '1965-02-28',
#  'Thomas Paine': '1737-02-09',
#  'Peter Straub ': '1943-03-02',
#  'Jana Petken ': 'none',
#  'Samuel R. George': 'none',
#  'Avi': 'none',
#  'Moira Young ': 'none',
#  'Christopher Hitchens': '1949-04-13',
#  'A.G. Howard ': 'none',
#  'J.K. Franko ': 'none',
#  'Taylor Jenkins Reid ': '1983-12-20',
#  'Sherwood Anderson': '1876-09-13',
#  'Kathleen Grissom ': 'none',
#  'Ted Bernal Guevara ': 'none',
#  'Blake Crouch ': '1978-10-15',
#  'Marie Rutkoski ': '1977-03-05',
#  'Barbara Ehrenreich': '1941-08-26',
#  'Vera Jane Cook ': 'none',
#  'Renée Ahdieh ': 'none',
#  'Anna Todd ': '1989-03-20',
#  'Carol Rifka Brunt ': 'none',
#  'William Landay ': '1963-07-23',
#  'M. Scott Peck': '1936-05-22',
#  'Alison Goodman ': 'none',
#  'Andrew Watson ': 'none',
#  'Joelle Charbonneau': 'none',
#  'Walter Moers': '1957-05-24',
#  'Kelly Creagh ': 'none',
#  'Morgan Matson ': 'none',
#  'Sergei Lukyanenko': '1968-04-11',
#  'David Clement-Davies ': '1964-01-06',
#  'Linda Masemore Pirrung': 'none',
#  'Thornton Wilder': '1897-04-17',
#  'Sandra Cisneros': '1954-12-20',
#  "Rom LcO'Feer": 'none',
#  'Steven Pressfield ': 'none',
#  'Tad Williams ': '1957-03-14',
#  'Juliet Marillier ': '1948-07-27',
#  'Brae Wyckoff ': 'none',
#  'Tom Rob Smith': '1979-02-19',
#  'Augustine of Hippo': 'none',
#  'Armistead Maupin': '1944-05-13',
#  'Robin LaFevers': 'none',
#  'Emma Chase ': 'none',
#  'Lindsay Anne Kendal ': 'none',
#  'Mark Bowden': '1951-07-17',
#  'William L. Shirer': '1904-02-23',
#  'Shelly Crane ': 'none',
#  'Jo Nesbø ': '1960-03-29',
#  'Simone de Beauvoir': '1908-01-09',
#  'Kresley Cole ': 'none',
#  'Richard Preston': '1954-08-05',
#  'Heather Morris ': '1987-02-01',
#  'James Alexander Thom': 'none',
#  'J.K. Accinni': 'none',
#  'Philippa Gregory ': '1954-01-09',
#  'Natsuki Takaya': '1973-07-07',
#  'Malcolm Lowry': '1909-07-28',
#  'Alex Michaelides ': 'none',
#  'Tom Wolfe': '1930-03-02',
#  'Jennifer Donnelly ': '1963-08-16',
#  'Ross Lockridge Jr.': '1914-04-25',
#  'Pat Frank': 'none',
#  'Dorothy L. Sayers': '1893-06-13',
#  'Amor Towles ': 'none',
#  'Jim Fergus ': 'none',
#  'Norman Mailer': '1923-01-31',
#  'Alison Croggon ': '1962',
#  'Patricia Highsmith': '1921-01-19',
#  'Jami Brumfield ': 'none',
#  'Irvin D. Yalom': '1931-06-13',
#  'Stella Gibbons': '1902-01-05',
#  'Holly Black ': '1971-11-10',
#  'Catherine Fisher': 'none',
#  'Amit Ray': '1960-08-12',
#  'Julia Hoban': 'none',
#  'Jude Deveraux': '1947-09-20',
#  'Darren Shan ': '1972-07-02',
#  'Robert Dugoni ': 'none',
#  'Anthony Horowitz ': '1955-04-05',
#  'Linda Watkins ': '1908-05-23',
#  'Eleanor H. Porter': '1868-12-19',
#  'Jean Rhys': '1890-08-24',
#  'Miguel Ruiz': 'none',
#  'Kimberly Derting ': 'none',
#  'Dennis Sharpe ': 'none',
#  'Lloyd Alexander': '1924-01-30',
#  'Raymond Carver': '1938-05-25',
#  'Joe Hill ': 'none',
#  'Jennifer Weiner ': '1970-03-28',
#  'Lisa McMann ': 'none',
#  'Darynda Jones ': 'none',
#  "Patrick O'Brian": 'none',
#  'Jeanette Winterson': '1959-08-27',
#  'Alexandre Dumas fils': '1824-07-27',
#  'Gordon B. Hinckley': '1995-03-12',
#  'Kendare Blake ': 'none',
#  'Patti Smith ': '1946-12-30',
#  'Mario Vargas Llosa': '1936-03-28',
#  'Chuck Dixon ': '1954-04-14',
#  'Rhys Bowen ': '1941-09-24',
#  'Spencer W. Kimball': '1973-12-30',
#  'Jodi Ellen Malpas ': 'none',
#  'Nelou Keramati ': 'none',
#  'Alison Bechdel': '1960-09-10',
#  'Edward Rutherfurd ': 'none',
#  'Alan Bradley ': 'none',
#  'Mahatma Gandhi': '1869-10-02',
#  'Courtney Allison Moulton ': '1986-08-16',
#  'Lian Hearn': '1942-08-29',
#  'A.D. Zoltan': 'none',
#  'Jennifer Egan ': 'none',
#  'Jack Finney': '1911-10-02',
#  'Ivan Goncharov': '1812-06-18',
#  'Daniel Kahneman': '1934-03-05',
#  'Mackenzi Lee ': 'none',
#  'John Fante': '1909-04-08',
#  'Dorothy Dunnett': '1923-08-25',
#  'Alfred Bester': '1913-12-18',
#  'Ken Grimwood': '1944-02-27',
#  'Lissa Price ': 'none',
#  'Samantha Shannon ': '1991-11-08',
#  'Tom Stoppard': '1937-07-03',
#  'Ayaan Hirsi Ali': '1969-11-13',
#  'Lili St. Crow': 'none',
#  'Michel Faber': '1960-04-13',
#  'J. Jupes ': 'none',
#  'Iain M. Banks': 'none',
#  'Sam Conniff ': 'none',
#  'John Galsworthy': '1867-08-14',
#  'Lynne Reid Banks': '1929-07-31',
#  'Kōbō Abe': '1924-03-07',
#  'ShelFoote': 'none',
#  'Lalita Tademy ': 'none',
#  'Sarah Dunant': '1950-08-08',
#  'Henry Fielding': '1707-04-22',
#  'Arkady Strugatsky': '1925-08-28',
#  'Thomas Wolfe': '1900-10-03',
#  'R.A. Salvatore': '1959-01-20',
#  'Margaret Weis ': '1948-03-16',
#  'Jennifer E. Smith ': 'none',
#  'Steven Erikson ': '1959-10-07',
#  'Kate Atkinson': 'none',
#  'Jennifer Crusie ': 'none',
#  'Judith McNaught': '1944-05-10',
#  'Angie Sage': '1952-06-20',
#  'James Allen': 'none',
#  'Rebecca Stead': '1968-01-16',
#  'Jennifer Brown': 'none',
#  'Ruth Ozeki ': '1956-03-12',
#  'Ira Levin': '1929-08-27',
#  'Jared Diamond': '1937-09-10',
#  'Mikhail Lermontov': 'none',
#  'Dave Barry': '1947-07-03',
#  'Anthony Ryan ': 'none',
#  'Ta-Nehisi Coates': '1975-09-30',
#  'David Wong ': 'none',
#  'Wendy Mass ': '1967-04-22',
#  'Pseudonymous Bosch ': '1967-10-25',
#  'Doris Kearns Goodwin': '1943-01-04',
#  'Marisha Pessl ': '1977-10-26',
#  'Crockett Johnson': '1906-10-20',
#  'Danielle Paige ': 'none',
#  'Patricia Daniels Cornwell': '1956-06-09',
#  'Hiromu Arakawa': '1973-05-08',
#  'Lois McMaster Bujold ': '1949-11-02',
#  'Thomas More': 'none',
#  'Sigrid Undset': '1882-05-20',
#  'L.A. Weatherly ': 'none',
#  'O. Henry': '1862-09-11',
#  'Paramahansa Yogananda': '1893-01-05',
#  'Leslie Garland ': 'none',
#  'Georges Bataille': '1897-09-10',
#  'Morgan Rhodes ': 'none',
#  'Tomi Adeyemi ': '1993-08-01',
#  'George S. Clason': 'none',
#  'Penelope Lively': '1933-03-17',
#  'Doris Lessing': '1919-10-22',
#  'John Katzenbach': '1950-06-23',
#  'Daniel Silva': 'none',
#  'Aimee Carter ': 'none',
#  'Robin S. Sharma': 'none',
#  'Kendra Elliot ': 'none',
#  'Edward Abbey': '1927-01-29',
#  'Gore Vidal': '1925-10-03',
#  'Paolo Giordano': 'none',
#  'Omar Khayyám': 'none',
#  'Forrest Carter': '1925-09-04',
#  'Frederick Douglass': 'none',
#  'Christine M. Knight ': 'none',
#  'Heinrich Böll': '1917-12-21',
#  'Susan Cooper ': '1935-05-23',
#  'Stefan Zweig': '1881-11-28',
#  'Theodore Taylor': 'none',
#  'Jay Kristoff ': 'none',
#  'Mira Grant': '1978-01-05',
#  'Jane Smiley ': '1949-09-26',
#  'Katherine Arden ': 'none',
#  'George Bernard Shaw': '1856-07-26',
#  'Åsne Seierstad': '1970-02-10',
#  'Nathanael West': '1903-10-17',
#  'Jessica Shirvington ': 'none',
#  'Tetsuko Kuroyanagi': '1933-08-09',
#  'MaryJanice Davidson ': 'none',
#  'Jay Crownover ': 'none',
#  'Jean Craighead George': '1919-07-02',
#  'Bernard Cornwell ': '1944-02-23',
#  'Christopher Pike': 'none',
#  'Kristen Britain': '1965-10-18',
#  'Adam Silvera ': '1990-06-07',
#  'Mahbod Seraji ': '1956-10-18',
#  'Annette Curtis Klause': 'none',
#  'Chris Cleave ': '1973-05-14',
#  ...}

# %%
# Converting dictionary to dataframe
df = pd.DataFrame.from_dict(author_dict, orient ='index')
df
# Out:
#                             0
# Suzanne Collins    1962-08-10
# J.K. Rowling       1965-07-31
# Stephenie Meyer    1973-12-24
# Markus Zusak       1975-06-23
# George Orwell            none
# ...                       ...
# Sarah Pinborough         none
# Neil Sheehan       1936-10-27
# Andy Andrews       1959-05-22
# Richard Rhodes     1937-07-04
# H.M. Ward                none
#
# [2725 rows x 1 columns]

# %%
df=df.reset_index()

# %%
df.to_csv('author_data.csv', index=False)
