# %%
# Imports
import pandas as pd

# %%
# Read the CSV file and put it into a dataframe

csv_file = 'Resources/original_book_data.csv'
book_df = pd.read_csv(csv_file, na_filter = True, na_values = '[]')
book_df.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
# 2  The unforgettable novel of a childhood in a sl...  English  9999999999999
# 3  Alternate cover edition of ISBN 9780679783268S...  English  9999999999999
# 4  About three things I was absolutely positive.\...  English  9780316015844
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
#
#                                           characters  ... firstPublishDate  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...              NaN
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...         06/21/03
# 2  ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...         07/11/60
# 3  ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...         01/28/13
# 4  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...         10/05/05
#
#                                               awards numRatings  \
# 0  ['Locus Award Nominee for Best Young Adult Boo...    6376780
# 1  ['Bram Stoker Award for Works for Young Reader...    2507623
# 2  ['Pulitzer Prize for Fiction (1961)', 'Audie A...    4501075
# 3                                                NaN    2998241
# 4  ['Georgia Peach Book Award (2007)', 'Buxtehude...    4964519
#
#                                       ratingsByStars likedPercent  \
# 0  ['3444695', '1921313', '745221', '171994', '93...         96.0
# 1  ['1593642', '637516', '222366', '39573', '14526']         98.0
# 2  ['2363896', '1333153', '573280', '149952', '80...         95.0
# 3  ['1617567', '816659', '373311', '113934', '767...         94.0
# 4  ['1751460', '1113682', '1008686', '542017', '5...         78.0
#
#                                              setting  \
# 0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1  ['Hogwarts School of Witchcraft and Wizardry (...
# 2               ['Maycomb, Alabama (United States)']
# 3  ['United Kingdom', 'Derbyshire, England (Unite...
# 4  ['Forks, Washington (United States)', 'Phoenix...
#
#                                             coverImg  bbeScore bbeVotes  price
# 0  https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516   5.09
# 1  https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923   7.38
# 2  https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328    NaN
# 3  https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452    NaN
# 4  https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874    2.1
#
# [5 rows x 25 columns]

# %% [markdown]
# Notes: Price is funky and has some blanks

# %%
# Store the columns we want in a new DF
book_df2 = book_df[['title', 'author','rating', 'description', 'language', 'isbn',
    'genres', 'pages', 'publishDate', 'publisher', 'numRatings', 'likedPercent']].copy()

    ## note - price is not included because there were many null values.
    ## we will get the price via web scraping

# Filter DF to only include books in English and drop null values
book_df2 = book_df2[book_df2['language'] == 'English']
book_df2.dropna(inplace = True)

book_df2.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
# 2  The unforgettable novel of a childhood in a sl...  English  9999999999999
# 3  Alternate cover edition of ISBN 9780679783268S...  English  9999999999999
# 4  About three things I was absolutely positive.\...  English  9780316015844
#
#                                               genres pages publishDate  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374    09/14/08
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870    09/28/04
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324    05/23/06
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279    10/10/00
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501    09/06/06
#
#                           publisher  numRatings  likedPercent
# 0                  Scholastic Press     6376780          96.0
# 1                   Scholastic Inc.     2507623          98.0
# 2  Harper Perennial Modern Classics     4501075          95.0
# 3                    Modern Library     2998241          94.0
# 4         Little, Brown and Company     4964519          78.0

# %%
# Determine the column dtypes
book_df2.dtypes
# Out:
# title            object
# author           object
# rating          float64
# description      object
# language         object
# isbn             object
# genres           object
# pages            object
# publishDate      object
# publisher        object
# numRatings        int64
# likedPercent    float64
# dtype: object

# %%
## convert the Title, Author, Language column to a string
book_df2['title'] = book_df2['title'].astype('string')
book_df2['author'] = book_df2['author'].astype('string')
book_df2['language'] = book_df2['language'].astype('string')

# %%
## convert the ISBN column to a string
book_df2['isbn'] = book_df2['isbn'].astype('string')

# drop books with the ISBN of 9999999999999
book_df2.drop(book_df2[book_df2['isbn'] == '9999999999999'].index, inplace = True)

# remove duplicate ISBN numbers
book_df2.drop_duplicates(subset=['isbn'], keep = 'first')

book_df2.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 4                                   Twilight
# 5                             The Book Thief
# 6                                Animal Farm
#
#                                               author  rating  \
# 0                                    Suzanne Collins    4.33
# 1          J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 4                                    Stephenie Meyer    3.60
# 5                    Markus Zusak (Goodreads Author)    4.37
# 6  George Orwell, Russell Baker (Preface), C.M. W...    3.95
#
#                                          description language           isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1  There is a door at the end of a silent corrido...  English  9780439358071
# 4  About three things I was absolutely positive.\...  English  9780316015844
# 5  Librarian's note: An alternate cover edition c...  English  9780375831003
# 6  Librarian's note: There is an Alternate Cover ...  English  9780451526342
#
#                                               genres pages publishDate  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374    09/14/08
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870    09/28/04
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501    09/06/06
# 5  ['Historical Fiction', 'Fiction', 'Young Adult...   552    03/14/06
# 6  ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...   141    04/28/96
#
#                    publisher  numRatings  likedPercent
# 0           Scholastic Press     6376780          96.0
# 1            Scholastic Inc.     2507623          98.0
# 4  Little, Brown and Company     4964519          78.0
# 5            Alfred A. Knopf     1834276          96.0
# 6            Signet Classics     2740713          91.0

# %%
test_df = book_df2[['author', 'isbn']].copy()
test_df = test_df.set_index('isbn')
test_df.head(12)
# Out:
#                                                           author
# isbn
# 9780439023481                                    Suzanne Collins
# 9780439358071          J.K. Rowling, Mary GrandPré (Illustrator)
# 9780316015844                                    Stephenie Meyer
# 9780375831003                    Markus Zusak (Goodreads Author)
# 9780451526342  George Orwell, Russell Baker (Preface), C.M. W...
# 9780345538376                                     J.R.R. Tolkien
# 9780446675536                                  Margaret Mitchell
# 9780060256654                                   Shel Silverstein
# 9780393978896  Emily Brontë, Richard J. Dunn (Editor), David ...
# 9781400096893                                      Arthur Golden
# 9780451527745  Lewis Carroll, John Tenniel (Illustrator), Mar...
# 9780142437209  Charlotte Brontë, Michael Mason (Editor), Barn...

# %%
# Split the Author Strings by a comma

new_df = pd.DataFrame(test_df['author'].str.split(pat=',', n=-1, expand=True))
new_df
# Out:
#                                                0  \
# isbn
# 9780439023481                    Suzanne Collins
# 9780439358071                       J.K. Rowling
# 9780316015844                    Stephenie Meyer
# 9780375831003    Markus Zusak (Goodreads Author)
# 9780451526342                      George Orwell
# ...                                          ...
# 9781477594247   Sherry Gammon (Goodreads Author)
# 2940012616562   Cheri Schmidt (Goodreads Author)
# 9781461017097  Kim Richardson (Goodreads Author)
# 9781450755634     Tom Pollack (Goodreads Author)
# 9781599554976    Misty Moncur (Goodreads Author)
#
#                                              1  \
# isbn
# 9780439023481                             <NA>
# 9780439358071      Mary GrandPré (Illustrator)
# 9780316015844                             <NA>
# 9780375831003                             <NA>
# 9780451526342          Russell Baker (Preface)
# ...                                        ...
# 9781477594247                             <NA>
# 2940012616562                             <NA>
# 9781461017097                             <NA>
# 9781450755634   John Loftus (Goodreads Author)
# 9781599554976                             <NA>
#
#                                             2     3     4     5     6     7  \
# isbn
# 9780439023481                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 9780439358071                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 9780316015844                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 9780375831003                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 9780451526342   C.M. Woodhouse (Introduction)  <NA>  <NA>  <NA>  <NA>  <NA>
# ...                                       ...   ...   ...   ...   ...   ...
# 9781477594247                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 2940012616562                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 9781461017097                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 9781450755634                       Jim Alves  <NA>  <NA>  <NA>  <NA>  <NA>
# 9781599554976                            <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
#
#                   8     9
# isbn
# 9780439023481  <NA>  <NA>
# 9780439358071  <NA>  <NA>
# 9780316015844  <NA>  <NA>
# 9780375831003  <NA>  <NA>
# 9780451526342  <NA>  <NA>
# ...             ...   ...
# 9781477594247  <NA>  <NA>
# 2940012616562  <NA>  <NA>
# 9781461017097  <NA>  <NA>
# 9781450755634  <NA>  <NA>
# 9781599554976  <NA>  <NA>
#
# [35665 rows x 10 columns]

# %%
# Keep only the index and column of the first author
author_table = new_df.loc[:, :0]

#name the author column 
author_table.columns = ['author']

author_table
# Out:
#                                           author
# isbn
# 9780439023481                    Suzanne Collins
# 9780439358071                       J.K. Rowling
# 9780316015844                    Stephenie Meyer
# 9780375831003    Markus Zusak (Goodreads Author)
# 9780451526342                      George Orwell
# ...                                          ...
# 9781477594247   Sherry Gammon (Goodreads Author)
# 2940012616562   Cheri Schmidt (Goodreads Author)
# 9781461017097  Kim Richardson (Goodreads Author)
# 9781450755634     Tom Pollack (Goodreads Author)
# 9781599554976    Misty Moncur (Goodreads Author)
#
# [35665 rows x 1 columns]

# %%
# Keep only the authors name
split_author = pd.DataFrame(author_table['author'].str.split(pat='(', n=-1, expand=True))
split_author
# Out:
#                              0                  1     2
# isbn
# 9780439023481  Suzanne Collins               <NA>  <NA>
# 9780439358071     J.K. Rowling               <NA>  <NA>
# 9780316015844  Stephenie Meyer               <NA>  <NA>
# 9780375831003    Markus Zusak   Goodreads Author)  <NA>
# 9780451526342    George Orwell               <NA>  <NA>
# ...                        ...                ...   ...
# 9781477594247   Sherry Gammon   Goodreads Author)  <NA>
# 2940012616562   Cheri Schmidt   Goodreads Author)  <NA>
# 9781461017097  Kim Richardson   Goodreads Author)  <NA>
# 9781450755634     Tom Pollack   Goodreads Author)  <NA>
# 9781599554976    Misty Moncur   Goodreads Author)  <NA>
#
# [35665 rows x 3 columns]

# %%
# Keep only the index and column of the first author
author_df = split_author.loc[:, :0]

#name the author column 
author_df.columns = ['main author']

#rename the index
author_df = author_df.rename(index = {'' : 'isbn'})

author_df
# Out:
#                    main author
# isbn
# 9780439023481  Suzanne Collins
# 9780439358071     J.K. Rowling
# 9780316015844  Stephenie Meyer
# 9780375831003    Markus Zusak
# 9780451526342    George Orwell
# ...                        ...
# 9781477594247   Sherry Gammon
# 2940012616562   Cheri Schmidt
# 9781461017097  Kim Richardson
# 9781450755634     Tom Pollack
# 9781599554976    Misty Moncur
#
# [35665 rows x 1 columns]

# %%
# export to csv to share with the team

author_df.to_csv('author_table.csv', index=True)

# %%
# merge data from the author table to the main data

main_book_data = pd.merge(book_df2, author_df, on = 'isbn')

#remove the original author column
main_book_data = main_book_data.drop(columns=['author'])

main_book_data
# Out:
#                                            title  rating  \
# 0                               The Hunger Games    4.33
# 1      Harry Potter and the Order of the Phoenix    4.50
# 2                                       Twilight    3.60
# 3                                 The Book Thief    4.37
# 4                                    Animal Farm    3.95
# ...                                          ...     ...
# 35710                               Unbelievable    4.16
# 35711                                  Fractured    4.00
# 35712                                     Marked    3.70
# 35713                                Wayward Son    3.85
# 35714                        Daughter of Helaman    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      About three things I was absolutely positive.\...  English
# 3      Librarian's note: An alternate cover edition c...  English
# 4      Librarian's note: There is an Alternate Cover ...  English
# ...                                                  ...      ...
# 35710  Lilah Lopez Dreser's in town to take care of u...  English
# 35711  The Fateful Trilogy continues with Fractured. ...  English
# 35712  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 35713  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 35714  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres pages  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 2      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# 3      9780375831003  ['Historical Fiction', 'Fiction', 'Young Adult...   552
# 4      9780451526342  ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...   141
# ...              ...                                                ...   ...
# 35710  9781477594247  ['Romance', 'Young Adult', 'Contemporary', 'Co...   360
# 35711  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0
# 35712  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 35713  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 35714  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate                  publisher  numRatings  \
# 0                09/14/08           Scholastic Press     6376780
# 1                09/28/04            Scholastic Inc.     2507623
# 2                09/06/06  Little, Brown and Company     4964519
# 3                03/14/06            Alfred A. Knopf     1834276
# 4                04/28/96            Signet Classics     2740713
# ...                   ...                        ...         ...
# 35710     April 11th 2013    Wordpaintings Unlimited        1028
# 35711       May 28th 2011              Cheri Schmidt         871
# 35712     March 18th 2011                CreateSpace        6674
# 35713  September 1st 2011        Cascada Productions         238
# 35714        May 8th 2011                 Bonneville         246
#
#        likedPercent      main author
# 0              96.0  Suzanne Collins
# 1              98.0     J.K. Rowling
# 2              78.0  Stephenie Meyer
# 3              96.0    Markus Zusak
# 4              91.0    George Orwell
# ...             ...              ...
# 35710          94.0   Sherry Gammon
# 35711          94.0   Cheri Schmidt
# 35712          84.0  Kim Richardson
# 35713          90.0     Tom Pollack
# 35714          90.0    Misty Moncur
#
# [35715 rows x 12 columns]

# %%
# Export to CSV file
main_book_data.to_csv('main_table.csv', index=True)
