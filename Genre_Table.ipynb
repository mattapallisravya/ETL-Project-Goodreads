# %% [markdown]
# Create the dataset for the Genre table

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Read the CSV file and put it into a dataframe

csv_file = 'filtered_data.csv'
book_df = pd.read_csv(csv_file)

#keep only the ISBN and Genre Column
genre_df = book_df[['isbn', 'genres']].copy()

genre_df.head()
# Out:
#             isbn                                             genres
# 0  9780062348678  ['Young Adult', 'Contemporary', 'LGBT', 'Roman...
# 1     B0745KTJSY  ['Historical Fiction', 'Fiction', 'Christian F...
# 2  9781408857908  ['Fantasy', 'Romance', 'Young Adult', 'New Adu...
# 3  9781786495259  ['Fiction', 'Romance', 'LGBT', 'Contemporary',...
# 4  9780143129554  ['Fiction', 'Classics', 'Literature', 'Novels'...

# %%
# genres = genre_df['genres'].str.split(pat=',', n=-1, expand=True)
# genres

# %%
# # Split the Author Strings by a comma

# new_df = pd.DataFrame(test_df['author'].str.split(pat=',', n=-1, expand=True))
# new_df

# %%
# genres.replace({'\'' : ''}, regex=True)
# genres

# %%
new_df = genre_df[['genres']]
genre_values = np.core.defchararray.split(new_df.values.astype('str'),',')
flatten_list = [item for sublist in genre_values for item in sublist]
flatten_list
# Out:
# [["['Young Adult'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Queer'",
#   " 'Realistic Fiction'",
#   " 'Coming Of Age'",
#   " 'Young Adult Contemporary']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Christian Fiction'",
#   " 'Classics'",
#   " 'Christian'",
#   " 'Romance'",
#   " 'Historical'",
#   " 'Young Adult'",
#   " 'Adult'",
#   " 'Inspirational']"],
#  ["['Fantasy'",
#   " 'Romance'",
#   " 'Young Adult'",
#   " 'New Adult'",
#   " 'Fae'",
#   " 'Magic'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'High Fantasy'",
#   " 'Paranormal']"],
#  ["['Fiction'",
#   " 'Romance'",
#   " 'LGBT'",
#   " 'Contemporary'",
#   " 'Queer'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Gay'",
#   " 'Coming Of Age'",
#   " 'M M Romance']"],
#  ["['Fiction'",
#   " 'Classics'",
#   " 'Literature'",
#   " 'Novels'",
#   " 'American'",
#   " 'Literary Fiction'",
#   " 'Contemporary'",
#   " 'Science Fiction'",
#   " '20th Century'",
#   " 'School']"],
#  ["['Contemporary'",
#   " 'Novels'",
#   " 'Book Club'",
#   " 'Adult'",
#   " 'True Story'",
#   " 'Fiction'",
#   " 'Drama'",
#   " 'Abuse'",
#   " 'New Adult'",
#   " 'Inspirational']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Literary Fiction'",
#   " 'Adult'",
#   " 'Novels'",
#   " 'Adult Fiction'",
#   " 'Queer'",
#   " 'Audiobook'",
#   " 'Literature']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Adventure'",
#   " 'Historical Fiction'",
#   " 'Science Fiction Fantasy'",
#   " 'Urban Fantasy']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Audiobook'",
#   " 'Young Adult Contemporary'",
#   " 'Teen'",
#   " 'Coming Of Age'",
#   " 'Young Adult Romance']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Science Fiction'",
#   " 'Romance'",
#   " 'Retellings'",
#   " 'Dystopia'",
#   " 'Fiction'",
#   " 'Fairy Tales'",
#   " 'Audiobook'",
#   " 'Adventure']"],
#  ["['Romance'",
#   " 'New Adult'",
#   " 'Contemporary'",
#   " 'Contemporary Romance'",
#   " 'Adult'",
#   " 'Disability'",
#   " 'Fiction'",
#   " 'Abuse'",
#   " 'Drama'",
#   " 'Erotica']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Paranormal'",
#   " 'Urban Fantasy'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Angels'",
#   " 'Vampires']"],
#  ["['Drama'",
#   " 'Contemporary'",
#   " 'Book Club'",
#   " 'Epic'",
#   " 'Fiction'",
#   " 'Novels']"],
#  ["['Poetry'", " 'Contemporary'", " 'Fiction']"],
#  ["['Fiction'",
#   " 'Poetry'",
#   " 'Classics'",
#   " 'Philosophy'",
#   " 'Literature'",
#   " 'Portugal'",
#   " 'Portuguese Literature'",
#   " 'Novels'",
#   " '20th Century'",
#   " 'Unfinished']"],
#  ["['Fiction'", " 'Contemporary'", " 'Drama'", " 'Epic'", " 'Novels']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Young Adult'",
#   " 'Novels'",
#   " 'New Adult'",
#   " 'Adult'",
#   " 'Drama'",
#   " 'Romance'",
#   " 'Mystery'",
#   " 'Love Story']"],
#  ["['Science Fiction'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Fantasy'",
#   " 'Audiobook'",
#   " 'Dystopia'",
#   " 'Space'",
#   " 'Adventure'",
#   " 'Thriller']"],
#  ["['Romance'",
#   " 'Contemporary'",
#   " 'New Adult'",
#   " 'Fiction'",
#   " 'Contemporary Romance'",
#   " 'Adult'",
#   " 'Abuse'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Young Adult']"],
#  ["['Picture Books'",
#   " 'Childrens'",
#   " 'Fiction'",
#   " 'Animals'",
#   " 'Humor'",
#   " 'Classics'",
#   " 'Fantasy'",
#   " 'Kids'",
#   " 'Food'",
#   " 'Storytime']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Paranormal'",
#   " 'Historical Fiction'",
#   " 'Time Travel'",
#   " 'Horror'",
#   " 'Mystery'",
#   " 'Adventure'",
#   " 'Supernatural']"],
#  ["['Fiction'",
#   " 'Historical Fiction'",
#   " 'Mystery'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Book Club'",
#   " 'Romance'",
#   " 'Adult Fiction'",
#   " 'Historical'",
#   " 'Coming Of Age']"],
#  ["['Romance'",
#   " 'New Adult'",
#   " 'Contemporary Romance'",
#   " 'Contemporary'",
#   " 'College'",
#   " 'Young Adult'",
#   " 'High School'",
#   " 'Coming Of Age'",
#   " 'Drama'",
#   " 'Adult']"],
#  ["['Fantasy']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Canada'",
#   " 'Historical'",
#   " 'Africa'",
#   " 'African American'",
#   " 'Adult Fiction'",
#   " 'Book Club'",
#   " 'Adult'",
#   " 'Literature']"],
#  ["['Young Adult'",
#   " 'Fiction'",
#   " 'Contemporary'",
#   " 'Mental Health'",
#   " 'Romance'",
#   " 'Audiobook'",
#   " 'Realistic Fiction'",
#   " 'Mental Illness'",
#   " 'Mystery'",
#   " 'Teen']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Plays'",
#   " 'Magic'",
#   " 'Adventure'",
#   " 'Drama'",
#   " 'Time Travel'",
#   " 'Childrens'",
#   " 'Middle Grade']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Dystopia'",
#   " 'Fantasy'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Science Fiction'",
#   " 'Teen'",
#   " 'Chick Lit'",
#   " 'Young Adult Fantasy']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Biography'",
#   " 'Audiobook'",
#   " 'Biography Memoir'",
#   " 'Autobiography'",
#   " 'Book Club'",
#   " 'Adult'",
#   " 'Education'",
#   " 'Religion']"],
#  ["['Fantasy'", " 'Middle Grade'", " 'Childrens']"],
#  ["['Fiction'",
#   " 'Mystery'",
#   " 'Contemporary'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Thriller'",
#   " 'Mystery Thriller'",
#   " 'Adult Fiction'",
#   " 'Australia']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Dystopia'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Science Fiction'",
#   " 'Magic'",
#   " 'High Fantasy']"],
#  ["['Thriller'",
#   " 'Crime'",
#   " 'Action'",
#   " 'Police'",
#   " 'Fiction'",
#   " 'Mystery']"],
#  ["['Post Apocalyptic'", " 'Literary Fiction'", " 'Dystopia']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'New Adult'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Fae'",
#   " 'High Fantasy'",
#   " 'Paranormal']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Mystery'",
#   " 'Audiobook'",
#   " 'Adventure'",
#   " 'High Fantasy']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Mythology'",
#   " 'Historical Fiction'",
#   " 'Audiobook'",
#   " 'Retellings'",
#   " 'Historical'",
#   " 'Adult'",
#   " 'Magic'",
#   " 'Adult Fiction']"],
#  ["['Fiction'",
#   " 'Fantasy'",
#   " 'Epic'",
#   " 'Drama'",
#   " 'Novels'",
#   " 'Young Adult'",
#   " 'Contemporary'",
#   " 'Adventure']"],
#  ["['Fiction'", " 'Contemporary'", " 'Epic'", " 'Novels'", " 'Drama']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Mental Health'",
#   " 'Book Club'",
#   " 'Novels'",
#   " 'Literary Fiction'",
#   " 'Chick Lit']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'High Fantasy'",
#   " 'Adventure'",
#   " 'Science Fiction Fantasy'",
#   " 'Audiobook'",
#   " 'Teen']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Biography'",
#   " 'Medicine'",
#   " 'Medical'",
#   " 'Audiobook'",
#   " 'Biography Memoir'",
#   " 'Autobiography'",
#   " 'Philosophy'",
#   " 'Science']"],
#  ["['Picture Books'",
#   " 'Childrens'",
#   " 'Fiction'",
#   " 'Classics'",
#   " 'Animals'",
#   " 'Family'",
#   " 'Rabbits'",
#   " 'Kids'",
#   " 'Love'",
#   " 'Fantasy']"],
#  ["['Drama'",
#   " 'Contemporary'",
#   " 'Book Club'",
#   " 'Thriller'",
#   " 'Suspense'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Epic'",
#   " 'Novels'",
#   " 'Dark']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Magic'",
#   " 'Fairy Tales'",
#   " 'High Fantasy'",
#   " 'Adult'",
#   " 'Retellings'",
#   " 'New Adult']"],
#  ["['Contemporary'", " 'Epic'", " 'Fiction'", " 'Drama'", " 'Novels']"],
#  ["['Contemporary'",
#   " 'Book Club'",
#   " 'Drama'",
#   " 'Epic'",
#   " 'Fiction'",
#   " 'Novels']"],
#  ["['Fantasy'",
#   " 'Mythology'",
#   " 'Young Adult'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'Urban Fantasy'",
#   " 'Magic'",
#   " 'Childrens'",
#   " 'Young Adult Fantasy']"],
#  ["['Epic'", " 'Contemporary'", " 'Fiction'", " 'Novels'", " 'Drama']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Historical'",
#   " 'Adult Fiction'",
#   " 'Chick Lit']"],
#  ["['Drama'",
#   " 'Mystery'",
#   " 'Crime'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Suspense'",
#   " 'Psychological Thriller'",
#   " 'Adult Fiction'",
#   " 'Novels'",
#   " 'Adventure']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Audiobook'",
#   " 'Mystery Thriller'",
#   " 'Adult'",
#   " 'Fantasy'",
#   " 'Science Fiction Fantasy'",
#   " 'Suspense']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Retellings'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Magic'",
#   " 'Historical Fiction'",
#   " 'Fairy Tales'",
#   " 'Historical']"],
#  ["['Parenting']"],
#  ["['Historical Fiction'",
#   " 'Young Adult'",
#   " 'Historical'",
#   " 'Fiction'",
#   " 'World War II'",
#   " 'War'",
#   " 'Audiobook'",
#   " 'Romance'",
#   " 'Teen'",
#   " 'Survival']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Epic Fantasy'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Magic'",
#   " 'Epic'",
#   " 'Science Fiction Fantasy'",
#   " 'Adventure']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Paranormal'",
#   " 'LGBT'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Urban Fantasy'",
#   " 'Audiobook'",
#   " 'Young Adult Fantasy']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Chick Lit'",
#   " 'Young Adult Contemporary'",
#   " 'Realistic Fiction'",
#   " 'High School'",
#   " 'Young Adult Romance']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Audiobook'",
#   " 'World War II'",
#   " 'Holocaust'",
#   " 'War'",
#   " 'Romance'",
#   " 'Adult'",
#   " 'Adult Fiction']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Suspense'",
#   " 'Crime'",
#   " 'Adult'",
#   " 'Psychological Thriller'",
#   " 'Contemporary']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Russia'",
#   " 'Historical'",
#   " 'Audiobook'",
#   " 'Book Club'",
#   " 'Literary Fiction'",
#   " 'Novels'",
#   " 'Adult Fiction'",
#   " 'Adult']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fae'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Audiobook'",
#   " 'Fairies'",
#   " 'Urban Fantasy']"],
#  ["['Fiction'",
#   " 'Classics'",
#   " 'Historical Fiction'",
#   " 'Literature'",
#   " 'Historical'",
#   " 'Feminism'",
#   " 'Literary Fiction'",
#   " 'Novels'",
#   " '20th Century'",
#   " 'School']"],
#  ["['Contemporary'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'New Adult'",
#   " 'Love Story'",
#   " 'Adult'",
#   " 'Romance'",
#   " 'Novels'",
#   " 'Contemporary Romance'",
#   " 'Chick Lit']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Magic'",
#   " 'High Fantasy'",
#   " 'Adventure'",
#   " 'Science Fiction Fantasy']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'Adult'",
#   " 'LGBT'",
#   " 'Romance'",
#   " 'Audiobook'",
#   " 'Adventure'",
#   " 'New Adult']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Contemporary'",
#   " 'Teen'",
#   " 'Young Adult Romance'",
#   " 'Family']"],
#  ["['Historical Fiction'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'World War II'",
#   " 'War'",
#   " 'British Literature'",
#   " 'Historical Mystery'",
#   " 'Audiobook'",
#   " 'Adult']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Urban Fantasy'",
#   " 'Science Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'New Adult'",
#   " 'Paranormal'",
#   " 'Paranormal Romance'",
#   " 'Fiction']"],
#  ["['Epic'",
#   " 'Contemporary'",
#   " 'Novels'",
#   " 'Drama'",
#   " 'Fiction'",
#   " 'Suspense']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Retellings'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Fairy Tales'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Magic'",
#   " 'Fairy Tale Retellings']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Philosophy'",
#   " 'Artificial Intelligence'",
#   " 'Young Adult'",
#   " 'Spirituality'",
#   " 'New Adult'",
#   " 'Dystopia']"],
#  ["['Historical Fiction'",
#   " 'Young Adult'",
#   " 'LGBT'",
#   " 'Romance'",
#   " 'Historical'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Queer'",
#   " 'Fantasy'",
#   " 'Adventure']"],
#  ["['Contemporary'",
#   " 'Novels'",
#   " 'Book Club'",
#   " 'Fiction'",
#   " 'Drama'",
#   " 'Epic']"],
#  ["['Nonfiction'",
#   " 'Business'",
#   " 'Self Help'",
#   " 'Philosophy'",
#   " 'Leadership'",
#   " 'Finance'",
#   " 'Personal Development'",
#   " 'Psychology']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Adult'",
#   " 'LGBT'",
#   " 'Audiobook'",
#   " 'Romance'",
#   " 'Adventure'",
#   " 'High Fantasy']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Race'",
#   " 'Audiobook'",
#   " 'History'",
#   " 'Biography'",
#   " 'Social Justice'",
#   " 'Essays'",
#   " 'Politics'",
#   " 'African American']"],
#  ["['Thriller'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Crime'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Horror']"],
#  ["['Fantasy'",
#   " 'Mythology'",
#   " 'Young Adult'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'LGBT'",
#   " 'Urban Fantasy'",
#   " 'Audiobook'",
#   " 'Childrens']"],
#  ["['Romance'",
#   " 'New Adult'",
#   " 'Contemporary'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Contemporary Romance'",
#   " 'Audiobook'",
#   " 'Chick Lit'",
#   " 'Adult'",
#   " 'Drama']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'New Adult'",
#   " 'Magic'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'High Fantasy'",
#   " 'Fae'",
#   " 'Paranormal']"],
#  ["['Science Fiction'",
#   " 'Fantasy'",
#   " 'Dystopia'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Audiobook'",
#   " 'Science Fiction Fantasy'",
#   " 'Adult'",
#   " 'Adventure'",
#   " 'Space']"],
#  ["['Fiction'", " 'Novels'", " 'Drama'", " 'Contemporary']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Romance'",
#   " 'Adventure'",
#   " 'High Fantasy'",
#   " 'Africa']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Fantasy'",
#   " 'Science Fiction Fantasy'",
#   " 'Classics'",
#   " 'Space Opera'",
#   " 'Audiobook'",
#   " 'Novels'",
#   " 'Speculative Fiction'",
#   " 'Space']"],
#  ["['Fiction'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Espionage'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Spy Thriller'",
#   " 'Novels'",
#   " 'Audiobook'",
#   " 'Adult']"],
#  ["['Mystery'",
#   " 'Romantic Suspense'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Suspense'",
#   " 'Contemporary'",
#   " 'Mystery Thriller'",
#   " 'Audiobook']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Music'",
#   " 'Historical'",
#   " 'Adult Fiction'",
#   " 'Romance'",
#   " 'Book Club']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Romantic Suspense'",
#   " 'Thriller'",
#   " 'Romance'",
#   " 'Suspense'",
#   " 'Crime'",
#   " 'Mystery Thriller'",
#   " 'Contemporary'",
#   " 'Audiobook']"],
#  ["['Historical Fiction'",
#   " 'Historical'",
#   " 'India'",
#   " 'Fiction'",
#   " 'Pakistan'",
#   " 'Medicine'",
#   " 'Medical'",
#   " 'Inspirational'",
#   " 'Cultural'",
#   " 'Doctors']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Adult'",
#   " 'New Adult'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'Young Adult Fantasy'",
#   " 'Magic'",
#   " 'Romance']"],
#  ["['Fantasy'",
#   " 'Historical Fiction'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Historical'",
#   " 'Fairy Tales'",
#   " 'Russia'",
#   " 'Mythology'",
#   " 'Adult'",
#   " 'Audiobook']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Audiobook'",
#   " 'Queer'",
#   " 'Science Fiction'",
#   " 'Fantasy'",
#   " 'Young Adult Contemporary']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Dystopia'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Science Fiction'",
#   " 'Magic'",
#   " 'High Fantasy']"],
#  ["['Psychology'",
#   " 'Business'",
#   " 'Nonfiction'",
#   " 'Economics'",
#   " 'Science'",
#   " 'Self Help'",
#   " 'Personal Development'",
#   " 'Finance'",
#   " 'Sociology'",
#   " 'Social Science']"],
#  ["['Romance'",
#   " 'Suspense'",
#   " 'Contemporary Romance'",
#   " 'Contemporary'",
#   " 'Romantic Suspense'",
#   " 'Erotica'",
#   " 'Mystery'",
#   " 'New Adult'",
#   " 'Adult'",
#   " 'Chick Lit']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Detective']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Paranormal'",
#   " 'Historical Fiction'",
#   " 'Adventure'",
#   " 'Audiobook'",
#   " 'Horror'",
#   " 'Time Travel'",
#   " 'Supernatural']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Audiobook'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Adult'",
#   " 'Detective'",
#   " 'Contemporary']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Crime'",
#   " 'Mystery Thriller'",
#   " 'Legal Thriller'",
#   " 'Audiobook'",
#   " 'Suspense'",
#   " 'Contemporary'",
#   " 'Adult']"],
#  ["['Contemporary'", " 'Fiction'", " 'Epic'", " 'Novels'", " 'Drama']"],
#  ["['Novels'",
#   " 'Fiction'",
#   " 'Contemporary'",
#   " 'Drama'",
#   " 'Book Club'",
#   " 'Epic'",
#   " 'Crime'",
#   " 'Dark']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Audiobook'",
#   " 'Sports'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Literary Fiction'",
#   " 'Book Club'",
#   " 'Sweden'",
#   " 'Realistic Fiction']"],
#  ["['Fiction'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Suspense'",
#   " 'Adventure'",
#   " 'Novels'",
#   " 'Crime'",
#   " 'Adult']"],
#  ["['Fantasy'",
#   " 'Romance'",
#   " 'LGBT'",
#   " 'M M Romance'",
#   " 'Adult'",
#   " 'Fiction'",
#   " 'Queer'",
#   " 'Historical'",
#   " 'New Adult'",
#   " 'High Fantasy']"],
#  ["['Drama'", " 'Fiction'", " 'Novels'", " 'Contemporary']"],
#  ["['Novels'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Historical Fiction'",
#   " 'New Adult'",
#   " 'Historical'",
#   " 'Adult'",
#   " 'Middle Grade'",
#   " 'Romance'",
#   " 'Adventure']"],
#  ["['Young Adult'",
#   " 'LGBT'",
#   " 'Contemporary'",
#   " 'Science Fiction'",
#   " 'Fiction'",
#   " 'Mental Health'",
#   " 'Romance'",
#   " 'Queer'",
#   " 'Fantasy'",
#   " 'Mental Illness']"],
#  ["['Epic'", " 'Contemporary']"],
#  ["['Contemporary'", " 'Novels'", " 'Fiction'", " 'Epic'", " 'Drama']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Suspense'",
#   " 'Romance'",
#   " 'Romantic Suspense'",
#   " 'Crime'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Contemporary']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Biography'",
#   " 'Audiobook'",
#   " 'Humor'",
#   " 'Autobiography'",
#   " 'Africa'",
#   " 'Biography Memoir'",
#   " 'Race'",
#   " 'South Africa']"],
#  ["['Epic'", " 'Contemporary'", " 'Drama'", " 'Book Club']"],
#  ["['Romance'",
#   " 'Young Adult'",
#   " 'Contemporary'",
#   " 'New Adult'",
#   " 'Mystery'",
#   " 'Paranormal'",
#   " 'Fiction'",
#   " 'Fantasy'",
#   " 'Suspense'",
#   " 'Contemporary Romance']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Fantasy'",
#   " 'Science Fiction Fantasy'",
#   " 'Space Opera'",
#   " 'Classics'",
#   " 'Philosophy'",
#   " 'Novels'",
#   " 'Speculative Fiction'",
#   " 'Religion']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Literary Fiction'",
#   " 'Book Club'",
#   " 'Novels'",
#   " 'Family'",
#   " 'Realistic Fiction']"],
#  ["['Epic'", " 'Drama'", " 'Fiction']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Crime'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Adult Fiction']"],
#  ["['Romance'",
#   " 'Coming Of Age'",
#   " 'Young Adult'",
#   " 'Dystopia'",
#   " 'Love'",
#   " 'War'",
#   " 'Fiction'",
#   " 'Science Fiction'",
#   " 'New Adult'",
#   " 'Post Apocalyptic']"],
#  ["['Book Club'", " 'Fiction'", " 'Contemporary'", " 'Novels'", " 'Drama']"],
#  ["['Thriller'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Suspense'",
#   " 'Mystery Thriller'",
#   " 'Psychological Thriller'",
#   " 'Audiobook'",
#   " 'Crime'",
#   " 'Adult'",
#   " 'Adult Fiction']"],
#  ["['Contemporary'", " 'Epic'", " 'Book Club'", " 'Christian'", " 'Drama']"],
#  ["['Contemporary'", " 'Book Club'", " 'Drama'", " 'Epic']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'Epic Fantasy'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Pirates'",
#   " 'Science Fiction Fantasy'",
#   " 'Crime']"],
#  ["['Book Club'",
#   " 'Fiction'",
#   " 'Contemporary'",
#   " 'Drama'",
#   " 'Novels'",
#   " 'Romance'",
#   " 'New Adult'",
#   " 'Fantasy']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Young Adult Fantasy'",
#   " 'Dystopia'",
#   " 'High Fantasy'",
#   " 'Fiction'",
#   " 'Historical Fiction'",
#   " 'Adventure'",
#   " 'War']"],
#  ["['Biography'",
#   " 'Nonfiction'",
#   " 'Business'",
#   " 'Science'",
#   " 'Technology'",
#   " 'Audiobook'",
#   " 'Biography Memoir'",
#   " 'Entrepreneurship'",
#   " 'Leadership'",
#   " 'Autobiography']"],
#  ["['Fiction'",
#   " 'Fantasy'",
#   " 'Magical Realism'",
#   " 'Adventure'",
#   " 'Spanish Literature'",
#   " 'Contemporary'",
#   " 'Family'",
#   " 'Audiobook'",
#   " 'Spain'",
#   " 'Drama']"],
#  ["['Contemporary'", " 'Fiction'", " 'Epic'", " 'Drama']"],
#  ["['Poetry'",
#   " 'Classics'",
#   " 'Feminism'",
#   " 'Fiction'",
#   " 'American'",
#   " '20th Century'",
#   " 'Literature'",
#   " 'Womens'",
#   " 'Mental Health'",
#   " 'Mental Illness']"],
#  ["['Romance'",
#   " 'Erotica'",
#   " 'BDSM'",
#   " 'Fiction'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Contemporary Romance'",
#   " 'Erotic Romance'",
#   " 'Chick Lit'",
#   " 'New Adult']"],
#  ["['Chick Lit'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Humor'",
#   " 'Contemporary Romance'",
#   " 'Love'",
#   " 'Fiction'",
#   " 'Clean Romance'",
#   " 'Womens Fiction'",
#   " 'British Literature']"],
#  ["['Fantasy'",
#   " 'Middle Grade'",
#   " 'Young Adult'",
#   " 'Fairy Tales'",
#   " 'Magic'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Childrens'",
#   " 'Adventure'",
#   " 'Audiobook']"],
#  ["['Nonfiction'",
#   " 'Psychology'",
#   " 'Self Help'",
#   " 'Philosophy'",
#   " 'Personal Development'",
#   " 'Audiobook'",
#   " 'Religion'",
#   " 'Unfinished'",
#   " 'Science'",
#   " 'Politics']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fae'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Audiobook'",
#   " 'Fairies'",
#   " 'Urban Fantasy']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Audiobook'",
#   " 'Book Club'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Family'",
#   " 'Adoption'",
#   " 'Contemporary']"],
#  ["['Contemporary'",
#   " 'Fiction'",
#   " 'Epic'",
#   " 'Science Fiction'",
#   " 'Historical Fiction'",
#   " 'Drama']"],
#  ["['Fantasy'",
#   " 'Romance'",
#   " 'Young Adult'",
#   " 'New Adult'",
#   " 'Fiction'",
#   " 'Fae'",
#   " 'Young Adult Fantasy'",
#   " 'Magic'",
#   " 'Paranormal'",
#   " 'Novella']"],
#  ["['Novels'", " 'Fiction'", " 'Contemporary'", " 'Epic']"],
#  ["['Romantic Suspense'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Suspense'",
#   " 'Adult'",
#   " 'Novels'",
#   " 'Drama'",
#   " 'Thriller'",
#   " 'Contemporary'",
#   " 'Crime']"],
#  ["['Fiction'", " 'Epic'", " 'Drama'", " 'Novels'", " 'Contemporary']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Urban Fantasy'",
#   " 'Paranormal'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Angels'",
#   " 'Audiobook']"],
#  ["['Short Stories'",
#   " 'Fiction'",
#   " 'Literary Fiction'",
#   " 'Literature'",
#   " 'Adult Fiction'",
#   " 'Dark'",
#   " 'Audiobook'",
#   " 'Mystery'",
#   " 'Adult'",
#   " 'Drama']"],
#  ["['Historical Fiction'",
#   " 'Young Adult'",
#   " 'Mystery'",
#   " 'Historical'",
#   " 'Horror'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Thriller'",
#   " 'Mystery Thriller']"],
#  ["['Vampires'",
#   " 'Young Adult'",
#   " 'Paranormal'",
#   " 'Fantasy'",
#   " 'Romance'",
#   " 'Paranormal Romance'",
#   " 'Supernatural'",
#   " 'Fiction'",
#   " 'Urban Fantasy'",
#   " 'Teen']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'World War II'",
#   " 'Historical'",
#   " 'War'",
#   " 'Italy'",
#   " 'Audiobook'",
#   " 'Book Club'",
#   " 'Adult'",
#   " 'Holocaust']"],
#  ["['Contemporary'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'New Adult'",
#   " 'Adult'",
#   " 'Novels'",
#   " 'Love Story'",
#   " 'Teen'",
#   " 'Middle Grade'",
#   " 'Music']"],
#  ["['Thriller'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Contemporary'",
#   " 'Mystery Thriller'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Suspense'",
#   " 'Horror'",
#   " 'Crime']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Dystopia'",
#   " 'Romance'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'High Fantasy'",
#   " 'Science Fiction'",
#   " 'Paranormal']"],
#  ["['Memoir'",
#   " 'Nonfiction'",
#   " 'Humor'",
#   " 'Biography Memoir'",
#   " 'Womens'",
#   " 'Biography'",
#   " 'Feminism'",
#   " 'Autobiography'",
#   " 'Relationships'",
#   " 'New York']"],
#  ["['Fiction'",
#   " 'Science Fiction'",
#   " 'Contemporary'",
#   " 'Dystopia'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Dark'",
#   " 'Thriller'",
#   " 'Cult Classics'",
#   " 'Drama']"],
#  ["['Mystery'",
#   " 'Romantic Suspense'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Suspense'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Mystery Thriller'",
#   " 'Drama']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Mental Health'",
#   " 'Chick Lit'",
#   " 'Mental Illness'",
#   " 'Audiobook'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Contemporary']"],
#  ["['Romance'",
#   " 'New Adult'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Contemporary Romance'",
#   " 'Young Adult'",
#   " 'Chick Lit'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Drama']"],
#  ["['Fiction'",
#   " 'Historical Fiction'",
#   " 'Classics'",
#   " 'Audiobook'",
#   " 'Historical'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Literature'",
#   " 'Literary Fiction'",
#   " 'Novels']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'Plays'",
#   " 'Adventure'",
#   " 'Historical Fiction'",
#   " 'Middle Grade'",
#   " 'Childrens'",
#   " 'Young Adult Fantasy']"],
#  ["['Psychology'",
#   " 'Philosophy'",
#   " 'Nonfiction'",
#   " 'Self Help'",
#   " 'Love'",
#   " 'Relationships'",
#   " 'Sociology'",
#   " 'Classics'",
#   " 'Spirituality'",
#   " 'German Literature']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Suspense'",
#   " 'Mystery Thriller'",
#   " 'Drama'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Psychological Thriller'",
#   " 'Young Adult']"],
#  ["['Thriller'",
#   " 'Romance'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Contemporary'",
#   " 'Suspense'",
#   " 'Adult'",
#   " 'Dark'",
#   " 'New Adult']"],
#  ["['New Adult'",
#   " 'Suspense'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Modern'",
#   " 'Young Adult'",
#   " 'Speculative Fiction'",
#   " 'Adventure'",
#   " '21st Century'",
#   " 'Drama']"],
#  ["['Horror'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Audiobook'",
#   " 'Mystery Thriller'",
#   " 'Fantasy'",
#   " 'Suspense'",
#   " 'Supernatural']"],
#  ["['Contemporary'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Mental Health'",
#   " 'Fiction'",
#   " 'Young Adult Contemporary'",
#   " 'Mental Illness'",
#   " 'Realistic Fiction'",
#   " 'High School'",
#   " 'Audiobook']"],
#  ["['Epic'",
#   " 'Novels'",
#   " 'Suspense'",
#   " 'Young Adult'",
#   " 'New Adult'",
#   " 'Book Club'",
#   " 'Fiction']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'New Adult'",
#   " 'Fiction'",
#   " 'Love Story'",
#   " 'Adult'",
#   " 'Romance'",
#   " 'Contemporary Romance'",
#   " 'Novels'",
#   " 'Chick Lit']"],
#  ["['Book Club'",
#   " 'Young Adult'",
#   " 'Drama'",
#   " 'Contemporary'",
#   " 'Epic'",
#   " 'New Adult']"],
#  ["['Historical Fiction'",
#   " 'Romance'",
#   " 'Time Travel'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Historical Romance'",
#   " 'Fantasy'",
#   " 'Ireland'",
#   " 'Audiobook'",
#   " 'Science Fiction']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Audiobook'",
#   " 'Adult Fiction'",
#   " 'Adult'",
#   " 'Book Club'",
#   " 'Realistic Fiction'",
#   " 'Race'",
#   " 'Drama'",
#   " 'Literary Fiction']"],
#  ["['Thriller'", " 'Action'", " 'Superheroes'", " 'Mystery'", " 'Crime']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Magical Realism'",
#   " 'Russia'",
#   " 'Young Adult'",
#   " 'Russian Literature'",
#   " 'Contemporary'",
#   " 'Audiobook'",
#   " 'Unfinished'",
#   " 'Cultural']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Urban Fantasy'",
#   " 'Paranormal'",
#   " 'Young Adult Fantasy'",
#   " 'LGBT'",
#   " 'Fiction'",
#   " 'Angels'",
#   " 'Magic']"],
#  ["['Paranormal'",
#   " 'Paranormal Romance'",
#   " 'Romance'",
#   " 'Fantasy'",
#   " 'Mythology'",
#   " 'Vampires'",
#   " 'Demons'",
#   " 'Humor'",
#   " 'Gods'",
#   " 'Urban Fantasy']"],
#  ["['Fiction'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Mystery Thriller'",
#   " 'Espionage'",
#   " 'Audiobook'",
#   " 'Suspense'",
#   " 'Contemporary'",
#   " 'Crime'",
#   " 'Novels']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Literary Fiction'",
#   " 'Abuse'",
#   " 'Dark'",
#   " 'Audiobook'",
#   " 'Coming Of Age']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Paranormal'",
#   " 'Dystopia'",
#   " 'Urban Fantasy'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Horror'",
#   " 'Science Fiction']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Audiobook'",
#   " 'World War II'",
#   " 'War'",
#   " 'France'",
#   " 'World War I'",
#   " 'Adult'",
#   " 'Book Club']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Detective']"],
#  ["['Young Adult'",
#   " 'Vampires'",
#   " 'Fantasy'",
#   " 'Paranormal'",
#   " 'Romance'",
#   " 'Magic'",
#   " 'Urban Fantasy'",
#   " 'Supernatural'",
#   " 'Paranormal Romance'",
#   " 'Witches']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Crime'",
#   " 'Suspense'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Detective']"],
#  ["['Dark'",
#   " 'Erotica'",
#   " 'Romance'",
#   " 'Adult'",
#   " 'New York'",
#   " 'Novels'",
#   " 'Crime'",
#   " 'Contemporary'",
#   " 'Love']"],
#  ["['Fiction'",
#   " 'Plays'",
#   " 'Contemporary'",
#   " 'Historical Fiction'",
#   " 'Drama'",
#   " 'Romance'",
#   " 'Theatre'",
#   " 'Tragedy'",
#   " 'Suspense'",
#   " 'Thriller']"],
#  ["['Humor'", " 'Nonfiction']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Science Fiction'",
#   " 'Retellings'",
#   " 'Dystopia'",
#   " 'Fiction'",
#   " 'Fairy Tales'",
#   " 'Romance'",
#   " 'Audiobook'",
#   " 'Novella']"],
#  ["['Business'",
#   " 'Nonfiction'",
#   " 'Leadership'",
#   " 'Psychology'",
#   " 'Self Help'",
#   " 'Society'",
#   " 'Money'",
#   " 'Finance'",
#   " 'Personal Development']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Crime'",
#   " 'Suspense'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Adult Fiction']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Mental Health'",
#   " 'Romance'",
#   " 'Mental Illness'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Contemporary'",
#   " 'Poetry'",
#   " 'Audiobook']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Africa'",
#   " 'Historical'",
#   " 'Literary Fiction'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Race'",
#   " 'Adult Fiction'",
#   " 'Ghana']"],
#  ["['Nonfiction'",
#   " 'Medicine'",
#   " 'Medical'",
#   " 'Science'",
#   " 'Memoir'",
#   " 'Biography'",
#   " 'Autobiography'",
#   " 'Health'",
#   " 'Biography Memoir'",
#   " 'Health Care']"],
#  ["['Fiction'",
#   " 'Historical Fiction'",
#   " 'War'",
#   " 'Asia'",
#   " 'Novels'",
#   " 'Historical'",
#   " 'Literary Fiction'",
#   " 'Literature'",
#   " 'Book Club'",
#   " 'Politics']"],
#  ["['Humor'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Mystery'",
#   " 'Magical Realism'",
#   " 'Paranormal'",
#   " 'Supernatural'",
#   " 'Fiction'",
#   " 'Contemporary'",
#   " 'Russia']"],
#  ["['Science Fiction'",
#   " 'Fantasy'",
#   " 'Fiction'",
#   " 'Dystopia'",
#   " 'Young Adult'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Science Fiction Fantasy'",
#   " 'Space Opera'",
#   " 'Space']"],
#  ["['Fantasy'",
#   " 'Romance'",
#   " 'New Adult'",
#   " 'Adult'",
#   " 'Urban Fantasy'",
#   " 'Fiction'",
#   " 'Paranormal'",
#   " 'Fae'",
#   " 'Magic'",
#   " 'Angels']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Mental Health'",
#   " 'Audiobook'",
#   " 'Young Adult Contemporary'",
#   " 'High School'",
#   " 'Teen']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Literary Fiction'",
#   " 'Ireland'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Novels'",
#   " 'Adult Fiction'",
#   " 'Irish Literature']"],
#  ["['Horror'",
#   " 'Fantasy'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Audiobook'",
#   " 'Mystery'",
#   " 'Science Fiction'",
#   " 'Adult'",
#   " 'Supernatural'",
#   " 'Dystopia']"],
#  ["['Young Adult'",
#   " 'Fantasy'",
#   " 'Dystopia'",
#   " 'Science Fiction'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Young Adult Fantasy'",
#   " 'Teen'",
#   " 'Romance'",
#   " 'Adventure']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Dystopia'",
#   " 'Magic'",
#   " 'Adult'",
#   " 'Young Adult Fantasy'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'New Adult']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Science Fiction'",
#   " 'Dystopia'",
#   " 'Superheroes'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Audiobook'",
#   " 'Young Adult Fantasy'",
#   " 'Adventure']"],
#  ["['Classics'",
#   " 'Fiction'",
#   " 'Childrens'",
#   " 'France'",
#   " 'French Literature'",
#   " 'Literature'",
#   " 'Adventure'",
#   " 'Novels'",
#   " '19th Century'",
#   " 'Young Adult']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Magic'",
#   " 'Dystopia'",
#   " 'High Fantasy'",
#   " 'Adventure']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Dystopia'",
#   " 'Fantasy'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Science Fiction'",
#   " 'Teen'",
#   " 'Chick Lit'",
#   " 'Young Adult Romance']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Mystery'",
#   " 'Adventure'",
#   " 'High Fantasy']"],
#  ["['Fiction'",
#   " 'Historical Fiction'",
#   " 'Contemporary'",
#   " 'Literary Fiction'",
#   " 'Novels'",
#   " 'Literature'",
#   " 'American'",
#   " 'Audiobook'",
#   " 'Americana'",
#   " 'The United States Of America']"],
#  ["['Fiction']"],
#  ["['Fantasy'",
#   " 'Adult'",
#   " 'Young Adult'",
#   " 'New Adult'",
#   " 'Fiction'",
#   " 'LGBT'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'Magic'",
#   " 'Romance']"],
#  ["['Fantasy'",
#   " 'Middle Grade'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'Childrens'",
#   " 'Young Adult Fantasy'",
#   " 'Contemporary'",
#   " 'Elves'",
#   " 'Romance']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Time Travel'",
#   " 'Audiobook'",
#   " 'Mystery'",
#   " 'Adult'",
#   " 'Mystery Thriller'",
#   " 'Science Fiction Fantasy'",
#   " 'Fantasy']"],
#  ["['Historical Fiction'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Historical'",
#   " 'Childrens'",
#   " 'World War II'",
#   " 'War'",
#   " 'Audiobook'",
#   " 'Juvenile']"],
#  ["['Fantasy'",
#   " 'Middle Grade'",
#   " 'Young Adult'",
#   " 'Adventure'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Childrens'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Urban Fantasy']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Fantasy'",
#   " 'Humor'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Book Club'",
#   " 'Family'",
#   " 'Sweden']"],
#  ["['Nonfiction'",
#   " 'Philosophy'",
#   " 'Essays'",
#   " 'History'",
#   " 'Science'",
#   " 'Psychology'",
#   " 'Audiobook'",
#   " 'Sociology'",
#   " 'Thriller'",
#   " 'Suspense']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Crime'",
#   " 'Contemporary'",
#   " 'Psychological Thriller'",
#   " 'Adult']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Psychology'",
#   " 'Self Help'",
#   " 'Mental Health'",
#   " 'Audiobook'",
#   " 'Biography'",
#   " 'Biography Memoir'",
#   " 'Adult'",
#   " 'Health']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Love Story'",
#   " 'Fiction'",
#   " 'New Adult'",
#   " 'Adult'",
#   " 'Romance'",
#   " 'Contemporary Romance'",
#   " 'Novels'",
#   " 'Chick Lit']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Crime'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Drama']"],
#  ["['Young Adult'",
#   " 'Fantasy'",
#   " 'Science Fiction'",
#   " 'Short Stories'",
#   " 'Retellings'",
#   " 'Romance'",
#   " 'Dystopia'",
#   " 'Fairy Tales'",
#   " 'Fiction'",
#   " 'Audiobook']"],
#  ["['Romance'",
#   " 'Mystery'",
#   " 'Romantic'",
#   " 'Love Story'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'New Adult'",
#   " 'Adventure'",
#   " '21st Century'",
#   " 'Modern']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'LGBT'",
#   " 'Audiobook'",
#   " 'Urban Fantasy'",
#   " 'Novella'",
#   " 'Queer'",
#   " 'Magical Realism']"],
#  ["['Fiction'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Drama'",
#   " 'Realistic Fiction'",
#   " 'Novels']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Magic'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Adventure'",
#   " 'High Fantasy'",
#   " 'Mythology'",
#   " 'Westerns']"],
#  ["['Dragons'",
#   " 'Fantasy'",
#   " 'Romance'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'Paranormal'",
#   " 'Paranormal Romance'",
#   " 'New Adult'",
#   " 'Supernatural'",
#   " 'Boarding School']"],
#  ["['Nonfiction'",
#   " 'History'",
#   " 'Philosophy'",
#   " 'Science'",
#   " 'Politics'",
#   " 'Audiobook'",
#   " 'Psychology'",
#   " 'Sociology'",
#   " 'Society'",
#   " 'Technology']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Mystery Thriller'",
#   " 'Contemporary'",
#   " 'Suspense'",
#   " 'Amazon'",
#   " 'Novels'",
#   " 'Drama']"],
#  ["['Fantasy'",
#   " 'Historical Fiction'",
#   " 'Young Adult'",
#   " 'Historical'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Retellings'",
#   " 'LGBT'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Mental Health'",
#   " 'Queer'",
#   " 'Mental Illness'",
#   " 'Young Adult Contemporary'",
#   " 'Realistic Fiction']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Science Fiction'",
#   " 'Romance'",
#   " 'Young Adult Fantasy'",
#   " 'Adventure'",
#   " 'Dystopia'",
#   " 'Teen'",
#   " 'High Fantasy']"],
#  ["['Fantasy'",
#   " 'Mythology'",
#   " 'Young Adult'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'LGBT'",
#   " 'Urban Fantasy'",
#   " 'Audiobook'",
#   " 'Magic']"],
#  ["['Politics'", " 'Nonfiction'", " 'Psychology']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'LGBT'",
#   " 'Fiction'",
#   " 'Paranormal'",
#   " 'Urban Fantasy'",
#   " 'Fae'",
#   " 'Magic'",
#   " 'Young Adult Fantasy']"],
#  ["['Nonfiction'",
#   " 'Humor'",
#   " 'Audiobook'",
#   " 'Biography'",
#   " 'Memoir'",
#   " 'Autobiography'",
#   " 'Contemporary'",
#   " 'Comedy'",
#   " 'Biography Memoir'",
#   " 'LGBT']"],
#  ["['Fantasy'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Childrens'",
#   " 'Adventure'",
#   " 'Fairy Tales'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'Audiobook'",
#   " 'Retellings']"],
#  ["['Young Adult'",
#   " 'LGBT'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Queer'",
#   " 'Science Fiction'",
#   " 'Mental Health'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Contemporary']"],
#  ["['Chick Lit'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Humor'",
#   " 'Contemporary Romance'",
#   " 'British Literature']"],
#  ["['Fiction'",
#   " 'Science Fiction'",
#   " 'Feminism'",
#   " 'Dystopia'",
#   " 'Fantasy'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Speculative Fiction'",
#   " 'Book Club'",
#   " 'Adult Fiction']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Mystery'",
#   " 'Adult Fiction'",
#   " 'Adult'",
#   " 'Australia'",
#   " 'Drama'",
#   " 'Thriller']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Dystopia'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Science Fiction'",
#   " 'Magic'",
#   " 'High Fantasy']"],
#  ["['Fiction'",
#   " 'Mystery'",
#   " 'Thriller'",
#   " 'Mystery Thriller'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Adult Fiction'",
#   " 'Crime']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Fairy Tales'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Mystery'",
#   " 'Magic'",
#   " 'Urban Fantasy'",
#   " 'Magical Realism']"],
#  ["['Thriller'",
#   " 'Horror'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Crime'",
#   " 'Suspense'",
#   " 'Adult'",
#   " 'Dark'",
#   " 'Audiobook']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Humor'",
#   " 'Asia'",
#   " 'Adult Fiction'",
#   " 'China']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Demons'",
#   " 'Adventure'",
#   " 'High Fantasy'",
#   " 'Paranormal'",
#   " 'Supernatural']"],
#  ["['Drama'", " 'Fiction'", " 'New Adult'", " 'Book Club'", " 'Fantasy']"],
#  ["['Science Fiction'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Fantasy'",
#   " 'Audiobook'",
#   " 'Space'",
#   " 'Dystopia'",
#   " 'Adventure'",
#   " 'Thriller']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Young Adult Fantasy'",
#   " 'Dystopia'",
#   " 'High Fantasy'",
#   " 'Fiction'",
#   " 'War'",
#   " 'Audiobook'",
#   " 'Adventure']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'LGBT'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Young Adult Contemporary'",
#   " 'Realistic Fiction'",
#   " 'Queer'",
#   " 'Mental Health']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Fiction'",
#   " 'Queer'",
#   " 'Realistic Fiction'",
#   " 'Mental Health'",
#   " 'Audiobook'",
#   " 'Romance'",
#   " 'Young Adult Contemporary']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Dystopia'",
#   " 'Young Adult Fantasy'",
#   " 'Magic'",
#   " 'Fiction'",
#   " 'High Fantasy'",
#   " 'Adventure'",
#   " 'Science Fiction']"],
#  ["['LGBT'",
#   " 'Young Adult'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Queer'",
#   " 'Realistic Fiction'",
#   " 'Transgender'",
#   " 'Romance'",
#   " 'Young Adult Contemporary'",
#   " 'Coming Of Age']"],
#  ["['Nonfiction'",
#   " 'Science'",
#   " 'Audiobook'",
#   " 'Physics'",
#   " 'Space'",
#   " 'Astronomy'",
#   " 'History'",
#   " 'Popular Science'",
#   " 'Adult'",
#   " 'Education']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Magic'",
#   " 'Romance'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'Teen'",
#   " 'Science Fiction Fantasy']"],
#  ["['Young Adult'",
#   " 'Magical Realism'",
#   " 'Contemporary'",
#   " 'Mental Health'",
#   " 'Fantasy'",
#   " 'Time Travel'",
#   " 'Fiction'",
#   " 'Mental Illness'",
#   " 'Science Fiction'",
#   " 'Romance']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Mental Health'",
#   " 'Fiction'",
#   " 'Mental Illness'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Contemporary'",
#   " 'Audiobook'",
#   " 'Death']"],
#  ["['Picture Books'",
#   " 'Sports'",
#   " 'Childrens'",
#   " 'Hockey'",
#   " 'Canada'",
#   " 'Realistic Fiction'",
#   " 'Fiction'",
#   " 'Middle Grade'",
#   " 'Adventure'",
#   " 'Contemporary']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Suspense'",
#   " 'Crime'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Psychological Thriller']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Chick Lit'",
#   " 'Young Adult Contemporary'",
#   " 'Realistic Fiction'",
#   " 'High School'",
#   " 'Fiction'",
#   " 'Contemporary Romance'",
#   " 'Young Adult Romance']"],
#  ["['Humor'",
#   " 'Indian Literature'",
#   " 'Literary Fiction'",
#   " 'Fiction'",
#   " 'Comedy'",
#   " 'India'",
#   " 'Thriller'",
#   " 'Adult Fiction'",
#   " 'Contemporary']"],
#  ["['Fantasy'", " 'Magic']"],
#  ["['Gaming'", " 'Business'", " 'Nonfiction'", " 'Sports'", " 'Games']"],
#  ["['Fiction'",
#   " 'Nature'",
#   " 'Literary Fiction'",
#   " 'Environment'",
#   " 'Contemporary'",
#   " 'Novels'",
#   " 'Historical Fiction'",
#   " 'Literature'",
#   " 'Book Club'",
#   " 'Audiobook']"],
#  ["['Paranormal'",
#   " 'Paranormal Romance'",
#   " 'Romance'",
#   " 'Fantasy'",
#   " 'Mythology'",
#   " 'Vampires'",
#   " 'Demons'",
#   " 'Urban Fantasy'",
#   " 'Humor'",
#   " 'Supernatural']"],
#  ["['Fiction'",
#   " 'Short Stories'",
#   " 'Horror'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Mystery Thriller'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Suspense'",
#   " 'Adult Fiction']"],
#  ["['Epic'", " 'Book Club'", " 'Action'", " 'Aliens']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Suspense'",
#   " 'Romance'",
#   " 'Romantic Suspense'",
#   " 'Fiction'",
#   " 'Crime'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Mystery Thriller']"],
#  ["['Nonfiction'",
#   " 'Science'",
#   " 'Psychology'",
#   " 'Economics'",
#   " 'History'",
#   " 'Politics'",
#   " 'Business'",
#   " 'Self Help'",
#   " 'Sociology'",
#   " 'Philosophy']"],
#  ["['Fantasy'",
#   " 'Mythology'",
#   " 'Young Adult'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'Greek Mythology'",
#   " 'Humor'",
#   " 'Childrens'",
#   " 'Audiobook']"],
#  ["['Nonfiction'",
#   " 'Self Help'",
#   " 'Writing'",
#   " 'Audiobook'",
#   " 'Personal Development'",
#   " 'Art'",
#   " 'Psychology'",
#   " 'Memoir'",
#   " 'Inspirational'",
#   " 'Business']"],
#  ["['Adventure'",
#   " 'War'",
#   " 'Drama'",
#   " 'Mystery'",
#   " 'Mystery Thriller'",
#   " 'Fiction'",
#   " 'Military Fiction'",
#   " 'New Adult'",
#   " 'Novels'",
#   " 'Adult Fiction']"],
#  ["['Young Adult'",
#   " 'Fantasy'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'LGBT'",
#   " 'Paranormal'",
#   " 'Mental Health'",
#   " 'Audiobook'",
#   " 'Romance'",
#   " 'Mental Illness']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Science Fiction'",
#   " 'Dystopia'",
#   " 'Romance'",
#   " 'Superheroes'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Young Adult Fantasy'",
#   " 'Adventure']"],
#  ["['Thriller'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Mystery Thriller'",
#   " 'Crime'",
#   " 'Suspense'",
#   " 'Contemporary'",
#   " 'Drama'",
#   " 'Amazon'",
#   " 'Action']"],
#  ["['Mystery'",
#   " 'Thriller'",
#   " 'Fiction'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Crime'",
#   " 'Adult Fiction'",
#   " 'Contemporary']"],
#  ["['Fiction'",
#   " 'Romance'",
#   " 'Chick Lit'",
#   " 'Contemporary'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Audiobook'",
#   " 'Contemporary Romance'",
#   " 'Family'",
#   " 'Humor']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Historical Fiction'",
#   " 'Literary Fiction'",
#   " 'Audiobook'",
#   " 'Novels'",
#   " 'Historical'",
#   " 'Literature'",
#   " 'British Literature'",
#   " 'Magical Realism']"],
#  ["['Mystery'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Crime'",
#   " 'Audiobook'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Detective'",
#   " 'Murder Mystery'",
#   " 'Adult']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Steampunk'",
#   " 'Mystery'",
#   " 'Young Adult'",
#   " 'Books About Books'",
#   " 'Science Fiction'",
#   " 'Urban Fantasy'",
#   " 'Magic'",
#   " 'Adventure']"],
#  ["['Fantasy'",
#   " 'Short Stories'",
#   " 'Fiction'",
#   " 'Horror'",
#   " 'Anthologies'",
#   " 'Urban Fantasy'",
#   " 'Science Fiction'",
#   " 'Science Fiction Fantasy'",
#   " 'Poetry'",
#   " 'Audiobook']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Post Apocalyptic'",
#   " 'Science Fiction Fantasy'",
#   " 'Audiobook'",
#   " 'Dystopia'",
#   " 'Space'",
#   " 'Fantasy'",
#   " 'Apocalyptic'",
#   " 'Speculative Fiction']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Adult'",
#   " 'Paranormal'",
#   " 'Urban Fantasy'",
#   " 'Contemporary'",
#   " 'Horror'",
#   " 'Magic'",
#   " 'Audiobook']"],
#  ["['Romance'",
#   " 'Young Adult'",
#   " 'Contemporary'",
#   " 'New Adult'",
#   " 'High School'",
#   " 'Abuse'",
#   " 'Humor'",
#   " 'Contemporary Romance'",
#   " 'Dark'",
#   " 'Fiction']"],
#  ["['Historical Fiction'",
#   " 'Historical'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Historical Romance'",
#   " 'Italy'",
#   " 'Adult'",
#   " 'Ancient History'",
#   " 'Drama'",
#   " 'Roman']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'LGBT'",
#   " 'Adult'",
#   " 'Dragons'",
#   " 'High Fantasy'",
#   " 'Queer'",
#   " 'Magic'",
#   " 'Romance'",
#   " 'Epic Fantasy']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'World War II'",
#   " 'War'",
#   " 'Germany'",
#   " 'Thriller'",
#   " 'Romance'",
#   " 'Novels'",
#   " 'Audiobook']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Audiobook'",
#   " 'Epic Fantasy'",
#   " 'Dragons'",
#   " 'High Fantasy'",
#   " 'Adult'",
#   " 'Science Fiction Fantasy'",
#   " 'Novels'",
#   " 'Unfinished']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Contemporary'",
# ...
#  ["['Dark'",
#   " 'Romance'",
#   " 'Erotica'",
#   " 'BDSM'",
#   " 'Abuse'",
#   " 'Suspense'",
#   " 'Adult'",
#   " 'Contemporary'",
#   " 'Erotic Romance'",
#   " 'Contemporary Romance']"],
#  ["['Nonfiction'",
#   " 'Self Help'",
#   " 'Psychology'",
#   " 'Personal Development'",
#   " 'Audiobook'",
#   " 'Leadership'",
#   " 'Mental Health'",
#   " 'Inspirational'",
#   " 'Business'",
#   " 'Spirituality']"],
#  ["['Short Stories']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Romance'",
#   " 'Art'",
#   " 'Audiobook'",
#   " 'Adult Fiction'",
#   " 'Adult'",
#   " 'Jewish'",
#   " 'France']"],
#  ["['Thriller'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Psychological Thriller'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Amazon'",
#   " 'Crime'",
#   " 'Drama'",
#   " 'Adult']"],
#  ["['Young Adult'",
#   " 'Romance'",
#   " 'Time Travel'",
#   " 'Science Fiction'",
#   " 'Historical Fiction'",
#   " 'Fantasy'",
#   " 'Historical'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Mystery']"],
#  ["['Fantasy'", " 'Supernatural']"],
#  ["['Paranormal Romance'",
#   " 'Angels'",
#   " 'Fantasy'",
#   " 'Paranormal'",
#   " 'Demons'",
#   " 'Urban Fantasy'",
#   " 'Young Adult'",
#   " 'Supernatural']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Cyberpunk'",
#   " 'Time Travel'",
#   " 'Science Fiction Fantasy'",
#   " 'Dystopia'",
#   " 'Speculative Fiction'",
#   " 'Audiobook'",
#   " 'Thriller'",
#   " 'Novels']"],
#  ["['Fantasy'",
#   " 'Historical Fiction'",
#   " 'Young Adult'",
#   " 'Historical'",
#   " 'Fiction'",
#   " 'Paranormal'",
#   " 'Ghosts'",
#   " 'Young Adult Fantasy'",
#   " 'Horror'",
#   " 'Supernatural']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Audiobook'",
#   " 'Romance'",
#   " 'High Fantasy'",
#   " 'Teen'",
#   " 'Dark']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Young Adult Contemporary'",
#   " 'Realistic Fiction'",
#   " 'High School'",
#   " 'Fantasy'",
#   " 'Time Travel'",
#   " 'Science Fiction']"],
#  ["['Fantasy'", " 'Young Adult']"],
#  ["['Thriller'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Mystery Thriller'",
#   " 'Crime'",
#   " 'Psychological Thriller'",
#   " 'Suspense'",
#   " 'Audiobook'",
#   " 'Contemporary'",
#   " 'Adult']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Biography'",
#   " 'War'",
#   " 'Disability'",
#   " 'Biography Memoir'",
#   " 'Autobiography'",
#   " 'History'",
#   " 'Audiobook'",
#   " 'Cultural']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Medieval'",
#   " 'Young Adult Fantasy'",
#   " 'Teen'",
#   " 'Historical'",
#   " 'High Fantasy']"],
#  ["['Contemporary'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Young Adult Contemporary'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Romance'",
#   " 'Contemporary Romance'",
#   " 'Audiobook'",
#   " 'Adventure']"],
#  ["['Romance'",
#   " 'Fiction'",
#   " 'Contemporary'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Adult Fiction'",
#   " 'Book Club'",
#   " 'Contemporary Romance'",
#   " 'Love']"],
#  ["['Graphic Novels'",
#   " 'Fantasy'",
#   " 'Comics'",
#   " 'Horror'",
#   " 'Fiction'",
#   " 'Steampunk'",
#   " 'Graphic Novels Comics'",
#   " 'Adult'",
#   " 'Comic Book'",
#   " 'Science Fiction']"],
#  ["['Philosophy'",
#   " 'Nonfiction'",
#   " 'Self Help'",
#   " 'Personal Development'",
#   " 'Psychology'",
#   " 'Spirituality'",
#   " 'Unfinished'",
#   " 'Business'",
#   " 'History'",
#   " 'Reference']"],
#  ["['Historical Fiction'",
#   " 'Fiction'",
#   " 'Mystery'",
#   " 'Retellings'",
#   " 'Romance'",
#   " 'Historical'",
#   " 'Gothic'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Adult Fiction']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Feminism'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Mental Health'",
#   " 'Young Adult Contemporary'",
#   " 'Family'",
#   " 'Love'",
#   " 'Realistic Fiction']"],
#  ["['Nonfiction'",
#   " 'Psychology'",
#   " 'Audiobook'",
#   " 'Self Help'",
#   " 'Sociology'",
#   " 'Science'",
#   " 'Business'",
#   " 'Personal Development'",
#   " 'Adult'",
#   " 'Communication']"],
#  ["['Romance'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Adult'",
#   " 'Contemporary Romance'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Sports'",
#   " 'Sports Romance'",
#   " 'Adult Fiction']"],
#  ["['Romance'",
#   " 'Fiction'",
#   " 'Contemporary'",
#   " 'Mystery Thriller'",
#   " 'Suspense'",
#   " 'Drama'",
#   " 'Contemporary Romance'",
#   " 'Dark'",
#   " 'Adult'",
#   " 'Thriller']"],
#  ["['Young Adult'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Teen'",
#   " 'Crime'",
#   " 'African American'",
#   " 'Contemporary'",
#   " 'School'",
#   " 'Mystery'",
#   " 'Audiobook']"],
#  ["['Romance'",
#   " 'Contemporary Romance'",
#   " 'Contemporary'",
#   " 'New Adult'",
#   " 'Erotica'",
#   " 'Adult'",
#   " 'Audiobook'",
#   " 'Chick Lit'",
#   " 'Erotic Romance'",
#   " 'Fiction']"],
#  ["['Nonfiction'",
#   " 'Philosophy'",
#   " 'Self Help'",
#   " 'Economics'",
#   " 'Business'",
#   " 'Psychology'",
#   " 'Society'",
#   " 'Politics'",
#   " 'Social Justice'",
#   " 'Personal Development']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Mental Health'",
#   " 'Mental Illness'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Realistic Fiction'",
#   " 'Fantasy'",
#   " 'Time Travel'",
#   " 'Science Fiction']"],
#  ["['Horror']"],
#  ["['Nonfiction'",
#   " 'Feminism'",
#   " 'Short Stories'",
#   " 'Childrens'",
#   " 'Biography'",
#   " 'History'",
#   " 'Middle Grade'",
#   " 'Womens'",
#   " 'Audiobook'",
#   " 'Picture Books']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Mythology'",
#   " 'High Fantasy'",
#   " 'Asian Literature'",
#   " 'Japan'",
#   " 'Magic']"],
#  ["['Nonfiction'",
#   " 'Memoir'",
#   " 'Biography Memoir'",
#   " 'India'",
#   " 'Autobiography'",
#   " 'Biography'",
#   " 'Amazon'",
#   " 'True Story'",
#   " 'Drama'",
#   " 'Survival']"],
#  ["['Fiction'",
#   " 'Mystery'",
#   " 'Poland'",
#   " 'Crime'",
#   " 'Polish Literature'",
#   " 'Literary Fiction'",
#   " 'Contemporary'",
#   " 'Novels'",
#   " 'Nobel Prize'",
#   " 'Mystery Thriller']"],
#  ["['Graphic Novels'",
#   " 'Young Adult'",
#   " 'LGBT'",
#   " 'Comics'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Queer'",
#   " 'Fiction'",
#   " 'Graphic Novels Comics'",
#   " 'Realistic Fiction']"],
#  ["['Historical Fiction'",
#   " 'Young Adult'",
#   " 'Middle Grade'",
#   " 'World War II'",
#   " 'Historical'",
#   " 'Fiction'",
#   " 'Holocaust'",
#   " 'War'",
#   " 'Audiobook'",
#   " 'Childrens']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Fiction'",
#   " 'Mental Health'",
#   " 'Realistic Fiction'",
#   " 'Mental Illness'",
#   " 'Audiobook'",
#   " 'Queer'",
#   " 'Teen']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'LGBT'",
#   " 'Science Fiction'",
#   " 'Dystopia'",
#   " 'Fiction'",
#   " 'Queer'",
#   " 'Romance'",
#   " 'Magic'",
#   " 'M M Romance']"],
#  ["['Fiction'",
#   " 'Historical Fiction'",
#   " 'Classics'",
#   " 'Coming Of Age'",
#   " 'Young Adult'",
#   " 'Humor'",
#   " 'World War II'",
#   " 'Literature'",
#   " 'Novels'",
#   " 'Book Club']"],
#  ["['Mythology'",
#   " 'Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Greek Mythology'",
#   " 'Retellings'",
#   " 'Paranormal'",
#   " 'Paranormal Romance'",
#   " 'Gods'",
#   " 'Fiction']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Paranormal'",
#   " 'Young Adult Fantasy'",
#   " 'Fiction'",
#   " 'Magic'",
#   " 'Urban Fantasy'",
#   " 'Supernatural'",
#   " 'Fae']"],
#  ["['Paranormal'",
#   " 'Paranormal Romance'",
#   " 'Romance'",
#   " 'Fantasy'",
#   " 'Vampires'",
#   " 'Demons'",
#   " 'Urban Fantasy'",
#   " 'Adult'",
#   " 'Fae'",
#   " 'Magic']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Abuse'",
#   " 'Feminism'",
#   " 'Young Adult Contemporary'",
#   " 'Thriller'",
#   " 'Mystery Thriller']"],
#  ["['Epic']"],
#  ["['Romance'",
#   " 'Paranormal Romance'",
#   " 'Science Fiction'",
#   " 'Fantasy'",
#   " 'Paranormal'",
#   " 'Aliens'",
#   " 'Adult'",
#   " 'Futuristic'",
#   " 'Fiction'",
#   " 'Science Fiction Romance']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Novels'",
#   " 'Literary Fiction'",
#   " 'Audiobook'",
#   " 'Queer'",
#   " 'Adult Fiction'",
#   " 'LGBT'",
#   " 'American'",
#   " 'Adult']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Retellings'",
#   " 'Romance'",
#   " 'Fairy Tales'",
#   " 'Magic'",
#   " 'Young Adult Fantasy'",
#   " 'Dragons'",
#   " 'Fiction'",
#   " 'High Fantasy']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'High Fantasy'",
#   " 'Epic Fantasy'",
#   " 'Audiobook'",
#   " 'Science Fiction'",
#   " 'Adventure'",
#   " 'Science Fiction Fantasy']"],
#  ["['Fantasy'",
#   " 'Retellings'",
#   " 'Young Adult'",
#   " 'Steampunk'",
#   " 'Dystopia'",
#   " 'Science Fiction'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Audiobook'",
#   " 'Romance']"],
#  ["['Science Fiction'",
#   " 'Fiction'",
#   " 'Space Opera'",
#   " 'Science Fiction Fantasy'",
#   " 'Space'",
#   " 'Audiobook'",
#   " 'Speculative Fiction'",
#   " 'Fantasy'",
#   " 'Adult'",
#   " 'Queer']"],
#  ["['Historical Fiction'",
#   " 'Young Adult'",
#   " 'Mystery'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Contemporary'",
#   " 'Realistic Fiction'",
#   " 'Mystery Thriller'",
#   " 'Teen'",
#   " 'Race']"],
#  ["['Erotica']"],
#  ["['Contemporary'", " 'Contemporary Romance'", " 'Erotica']"],
#  ["['Nonfiction'",
#   " 'Self Help'",
#   " 'Spirituality'",
#   " 'Philosophy'",
#   " 'Religion'",
#   " 'Buddhism'",
#   " 'Audiobook'",
#   " 'Psychology'",
#   " 'Inspirational'",
#   " 'Personal Development']"],
#  ["['Fantasy'",
#   " 'Fiction'",
#   " 'Epic Fantasy'",
#   " 'Magic'",
#   " 'High Fantasy'",
#   " 'Audiobook'",
#   " 'Dark Fantasy'",
#   " 'Demons'",
#   " 'Epic'",
#   " 'Adventure']"],
#  ["['Contemporary'",
#   " 'Young Adult'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Music'",
#   " 'Mental Health'",
#   " 'Young Adult Contemporary'",
#   " 'Realistic Fiction'",
#   " 'Family'",
#   " 'Abuse']"],
#  ["['Poetry'",
#   " 'Fiction'",
#   " 'Magical Realism'",
#   " 'Contemporary'",
#   " 'Literary Fiction'",
#   " 'Novella'",
#   " 'Death'",
#   " 'Novels'",
#   " 'Fantasy'",
#   " 'Short Stories']"],
#  ["['Biography'",
#   " 'Nonfiction'",
#   " 'History'",
#   " 'Art'",
#   " 'Science'",
#   " 'Biography Memoir'",
#   " 'Audiobook'",
#   " 'Italy'",
#   " 'Historical'",
#   " 'Art History']"],
#  ["['Fiction']"],
#  ["['History'",
#   " 'Nonfiction'",
#   " 'India'",
#   " 'Politics'",
#   " 'Historical'",
#   " 'Indian Literature'",
#   " 'Asia'",
#   " 'Race'",
#   " 'Economics'",
#   " 'Audiobook']"],
#  ["['Fiction'",
#   " 'Feminism'",
#   " 'Contemporary'",
#   " 'Short Stories'",
#   " 'Literary Fiction'",
#   " 'LGBT'",
#   " 'Race'",
#   " 'Audiobook'",
#   " 'Queer'",
#   " 'Novels']"],
#  ["['Nonfiction'",
#   " 'Self Help'",
#   " 'Spirituality'",
#   " 'Philosophy'",
#   " 'Audiobook'",
#   " 'Psychology'",
#   " 'Buddhism'",
#   " 'Personal Development'",
#   " 'Religion'",
#   " 'Inspirational']"],
#  ["['Short Stories'",
#   " 'Fiction'",
#   " 'Magical Realism'",
#   " 'Fantasy'",
#   " 'Adult'",
#   " 'Literary Fiction'",
#   " 'Contemporary'",
#   " 'LGBT'",
#   " 'Adult Fiction'",
#   " 'Queer']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Books About Books'",
#   " 'Young Adult Contemporary'",
#   " 'Audiobook'",
#   " 'Family'",
#   " 'Australia']"],
#  ["['Fantasy'",
#   " 'Middle Grade'",
#   " 'Science Fiction'",
#   " 'Adventure'",
#   " 'Fiction'",
#   " 'Action'",
#   " 'Childrens'",
#   " 'Animals'",
#   " 'Young Adult'",
#   " 'Juvenile']"],
#  ["['Fiction'",
#   " 'France'",
#   " 'Literary Fiction'",
#   " 'Contemporary'",
#   " 'Literature'",
#   " 'Novels'",
#   " 'Adult Fiction'",
#   " 'Roman'",
#   " 'French Literature'",
#   " 'Medicine']"],
#  ["['Mystery']"],
#  ["['Thriller'",
#   " 'Fiction'",
#   " 'Adventure'",
#   " 'Mystery'",
#   " 'Action'",
#   " 'Science Fiction'",
#   " 'Suspense'",
#   " 'Mystery Thriller'",
#   " 'Historical Fiction'",
#   " 'Audiobook']"],
#  ["['Romance'",
#   " 'Contemporary'",
#   " 'Contemporary Romance'",
#   " 'Humor'",
#   " 'Adult'",
#   " 'New Adult'",
#   " 'Erotica'",
#   " 'Chick Lit'",
#   " 'Audiobook'",
#   " 'Fiction']"],
#  ["['Fantasy'",
#   " 'Romance'",
#   " 'LGBT'",
#   " 'Short Stories'",
#   " 'M M Romance'",
#   " 'Adult'",
#   " 'Fiction'",
#   " 'Historical'",
#   " 'Novella'",
#   " 'Queer']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Realistic Fiction'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'High School'",
#   " 'Audiobook'",
#   " 'Mental Health'",
#   " 'Family'",
#   " 'Young Adult Contemporary']"],
#  ["['Romance'",
#   " 'Dark'",
#   " 'New Adult'",
#   " 'Contemporary'",
#   " 'Contemporary Romance'",
#   " 'College'",
#   " 'Suspense'",
#   " 'Erotica'",
#   " 'Adult'",
#   " 'Abuse']"],
#  ["['Nonfiction'",
#   " 'Self Help'",
#   " 'Audiobook'",
#   " 'Memoir'",
#   " 'Biography'",
#   " 'Humor'",
#   " 'Business'",
#   " 'Personal Development'",
#   " 'Feminism'",
#   " 'Autobiography']"],
#  ["['Science'",
#   " 'Nonfiction'",
#   " 'Psychology'",
#   " 'Biology'",
#   " 'Neuroscience'",
#   " 'Philosophy'",
#   " 'Audiobook'",
#   " 'Sociology'",
#   " 'History'",
#   " 'Anthropology']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Science Fiction'",
#   " 'Dystopia'",
#   " 'Fiction'",
#   " 'Urban Fantasy'",
#   " 'Audiobook'",
#   " 'Superheroes'",
#   " 'Post Apocalyptic'",
#   " 'Adventure']"],
#  ["['Young Adult'",
#   " 'Feminism'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Young Adult Contemporary'",
#   " 'Mental Health'",
#   " 'Realistic Fiction'",
#   " 'High School'",
#   " 'Humor']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Magic'",
#   " 'Fiction'",
#   " 'High Fantasy'",
#   " 'Young Adult Fantasy'",
#   " 'Adult'",
#   " 'Adventure'",
#   " 'Romance'",
#   " 'Audiobook']"],
#  ["['Leadership'",
#   " 'Business'",
#   " 'Nonfiction'",
#   " 'Self Help'",
#   " 'Personal Development'",
#   " 'Military Fiction'",
#   " 'Management'",
#   " 'Audiobook'",
#   " 'Psychology'",
#   " 'Productivity']"],
#  ["['Fantasy'",
#   " 'Middle Grade'",
#   " 'Fiction'",
#   " 'Young Adult'",
#   " 'Historical Fiction'",
#   " 'Childrens'",
#   " 'Adventure'",
#   " 'Audiobook'",
#   " 'Magic'",
#   " 'Juvenile']"],
#  ["['Fantasy'",
#   " 'Historical Fiction'",
#   " 'Young Adult'",
#   " 'Historical'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Magic'",
#   " 'Historical Fantasy'",
#   " 'Audiobook']"],
#  ["['Fantasy'",
#   " 'Young Adult'",
#   " 'Horror'",
#   " 'Paranormal'",
#   " 'Urban Fantasy'",
#   " 'Supernatural'",
#   " 'Fiction'",
#   " 'Young Adult Fantasy'",
#   " 'Dark'",
#   " 'Thriller']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Romance'",
#   " 'Fiction'",
#   " 'Realistic Fiction'",
#   " 'Young Adult Contemporary'",
#   " 'Audiobook'",
#   " 'Teen'",
#   " 'Young Adult Romance'",
#   " 'Historical Fiction']"],
#  ["['Light Novel'",
#   " 'Fantasy'",
#   " 'Romance'",
#   " 'Young Adult'",
#   " 'Manga'",
#   " 'Japanese Literature'",
#   " 'Slice Of Life'",
#   " 'Fiction'",
#   " 'Novels'",
#   " 'Japan']"],
#  ["['Fiction'",
#   " '21st Century'",
#   " 'Short Stories'",
#   " 'Contemporary'",
#   " 'Indian Literature']"],
#  ["['Chick Lit'",
#   " 'Fiction'",
#   " 'Romance'",
#   " 'Humor'",
#   " 'Novels'",
#   " 'Comedy'",
#   " 'Contemporary'",
#   " 'British Literature'",
#   " 'Indonesian Literature'",
#   " 'Drama']"],
#  ["['Dark'",
#   " 'Romance'",
#   " 'Contemporary'",
#   " 'Abuse'",
#   " 'Suspense'",
#   " 'Romantic Suspense'",
#   " 'Contemporary Romance'",
#   " 'Adult'",
#   " 'Crime'",
#   " 'Erotica']"],
#  ["['Young Adult'",
#   " 'Contemporary'",
#   " 'Magical Realism'",
#   " 'Fiction'",
#   " 'Mental Health'",
#   " 'Fantasy'",
#   " 'Teen'",
#   " 'Realistic Fiction'",
#   " 'Mental Illness'",
#   " 'Audiobook']"],
#  ["['Fiction']"],
#  ["['Romance'",
#   " 'Contemporary'",
#   " 'New Adult'",
#   " 'Contemporary Romance'",
#   " 'Fiction'",
#   " 'Adult'",
#   " 'Chick Lit'",
#   " 'Abuse'",
#   " 'Young Adult'",
#   " 'Adult Fiction']"],
#  ["['Mystery'",
#   " 'Young Adult'",
#   " 'Contemporary'",
#   " 'Fiction'",
#   " 'Retellings'",
#   " 'Audiobook'",
#   " 'Mystery Thriller'",
#   " 'Romance'",
#   " 'Teen'",
#   " 'Crime']"],
#  ["['Middle Grade'",
#   " 'Realistic Fiction'",
#   " 'Sports'",
#   " 'Young Adult'",
#   " 'Fiction'",
#   " 'Family'",
#   " 'Audiobook'",
#   " 'Contemporary'",
#   " 'Juvenile'",
#   " 'Childrens']"],
#  ["['Horror'",
#   " 'Fiction'",
#   " 'Thriller'",
#   " 'Mystery'",
#   " 'Paranormal'",
#   " 'Audiobook'",
#   " 'Adult'",
#   " 'Suspense'",
#   " 'Supernatural'",
#   " 'Mystery Thriller']"],
#  ["['Fiction'",
#   " 'Contemporary'",
#   " 'Literary Fiction'",
#   " 'Audiobook'",
#   " 'Adult Fiction'",
#   " 'Family'",
#   " 'Adult'",
#   " 'India'",
#   " 'Book Club'",
#   " 'Novels']"],
#  ...]

# %%
for x in flatten_list:
    if x 
    print(x)
# Out:
#   File "C:\Users\laure\AppData\Local\Temp\ipykernel_2232\3269240068.py", line 2
#     if x
#          ^
# SyntaxError: invalid syntax

# %%
n_genre_values = genre_values.tolist().copy()

#res = [sub.replace('[', '') for sub in n_genre_values]

for x in n_genre_values:
    print()

# %%
genre_df2 = genre_df.copy()
genre_df2['genres'] = genre_df2['genres'].str.replace('[', '')
genre_df2['genres'] = genre_df2['genres'].str.replace(']', '')
genre_df2['genres'] = genre_df2['genres'].str.replace("'", "")
genre_df2
# Out:
#                isbn                                             genres
# 0     9780062348678  Young Adult, Contemporary, LGBT, Romance, Fict...
# 1        B0745KTJSY  Historical Fiction, Fiction, Christian Fiction...
# 2     9781408857908  Fantasy, Romance, Young Adult, New Adult, Fae,...
# 3     9781786495259  Fiction, Romance, LGBT, Contemporary, Queer, A...
# 4     9780143129554  Fiction, Classics, Literature, Novels, America...
# ...             ...                                                ...
# 3810  9781250078285  Graphic Novels, Young Adult, Science Fiction, ...
# 3811  9781447256274  Fantasy, Fiction, Steampunk, Mystery, Urban Fa...
# 3812     B01KZOA32U  Mystery, Thriller, Fiction, Suspense, Mystery ...
# 3813     B00XKC1KTK                     Survival, Contemporary Romance
# 3814  9781760111236  Fiction, Dystopia, Australia, Feminism, Scienc...
#
# [3815 rows x 2 columns]

# %%
new_df = genre_df2['genres'].copy()

genre_values = np.core.defchararray.split(new_df.values.astype('str'),', ')
flatten_list = [item for sublist in genre_values for item in sublist]
flatten_list
# Out:
# ['Young Adult',
#  'Contemporary',
#  'LGBT',
#  'Romance',
#  'Fiction',
#  'Audiobook',
#  'Queer',
#  'Realistic Fiction',
#  'Coming Of Age',
#  'Young Adult Contemporary',
#  'Historical Fiction',
#  'Fiction',
#  'Christian Fiction',
#  'Classics',
#  'Christian',
#  'Romance',
#  'Historical',
#  'Young Adult',
#  'Adult',
#  'Inspirational',
#  'Fantasy',
#  'Romance',
#  'Young Adult',
#  'New Adult',
#  'Fae',
#  'Magic',
#  'Fiction',
#  'Young Adult Fantasy',
#  'High Fantasy',
#  'Paranormal',
#  'Fiction',
#  'Romance',
#  'LGBT',
#  'Contemporary',
#  'Queer',
#  'Audiobook',
#  'Adult',
#  'Gay',
#  'Coming Of Age',
#  'M M Romance',
#  'Fiction',
#  'Classics',
#  'Literature',
#  'Novels',
#  'American',
#  'Literary Fiction',
#  'Contemporary',
#  'Science Fiction',
#  '20th Century',
#  'School',
#  'Contemporary',
#  'Novels',
#  'Book Club',
#  'Adult',
#  'True Story',
#  'Fiction',
#  'Drama',
#  'Abuse',
#  'New Adult',
#  'Inspirational',
#  'Fiction',
#  'Contemporary',
#  'LGBT',
#  'Literary Fiction',
#  'Adult',
#  'Novels',
#  'Adult Fiction',
#  'Queer',
#  'Audiobook',
#  'Literature',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Magic',
#  'Adult',
#  'Audiobook',
#  'Adventure',
#  'Historical Fiction',
#  'Science Fiction Fantasy',
#  'Urban Fantasy',
#  'Young Adult',
#  'Romance',
#  'Contemporary',
#  'Fiction',
#  'Realistic Fiction',
#  'Audiobook',
#  'Young Adult Contemporary',
#  'Teen',
#  'Coming Of Age',
#  'Young Adult Romance',
#  'Fantasy',
#  'Young Adult',
#  'Science Fiction',
#  'Romance',
#  'Retellings',
#  'Dystopia',
#  'Fiction',
#  'Fairy Tales',
#  'Audiobook',
#  'Adventure',
#  'Romance',
#  'New Adult',
#  'Contemporary',
#  'Contemporary Romance',
#  'Adult',
#  'Disability',
#  'Fiction',
#  'Abuse',
#  'Drama',
#  'Erotica',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'Paranormal',
#  'Urban Fantasy',
#  'Young Adult Fantasy',
#  'Fiction',
#  'Magic',
#  'Angels',
#  'Vampires',
#  'Drama',
#  'Contemporary',
#  'Book Club',
#  'Epic',
#  'Fiction',
#  'Novels',
#  'Poetry',
#  'Contemporary',
#  'Fiction',
#  'Fiction',
#  'Poetry',
#  'Classics',
#  'Philosophy',
#  'Literature',
#  'Portugal',
#  'Portuguese Literature',
#  'Novels',
#  '20th Century',
#  'Unfinished',
#  'Fiction',
#  'Contemporary',
#  'Drama',
#  'Epic',
#  'Novels',
#  'Fiction',
#  'Contemporary',
#  'Young Adult',
#  'Novels',
#  'New Adult',
#  'Adult',
#  'Drama',
#  'Romance',
#  'Mystery',
#  'Love Story',
#  'Science Fiction',
#  'Young Adult',
#  'Romance',
#  'Fiction',
#  'Fantasy',
#  'Audiobook',
#  'Dystopia',
#  'Space',
#  'Adventure',
#  'Thriller',
#  'Romance',
#  'Contemporary',
#  'New Adult',
#  'Fiction',
#  'Contemporary Romance',
#  'Adult',
#  'Abuse',
#  'Chick Lit',
#  'Audiobook',
#  'Young Adult',
#  'Picture Books',
#  'Childrens',
#  'Fiction',
#  'Animals',
#  'Humor',
#  'Classics',
#  'Fantasy',
#  'Kids',
#  'Food',
#  'Storytime',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Paranormal',
#  'Historical Fiction',
#  'Time Travel',
#  'Horror',
#  'Mystery',
#  'Adventure',
#  'Supernatural',
#  'Fiction',
#  'Historical Fiction',
#  'Mystery',
#  'Audiobook',
#  'Adult',
#  'Book Club',
#  'Romance',
#  'Adult Fiction',
#  'Historical',
#  'Coming Of Age',
#  'Romance',
#  'New Adult',
#  'Contemporary Romance',
#  'Contemporary',
#  'College',
#  'Young Adult',
#  'High School',
#  'Coming Of Age',
#  'Drama',
#  'Adult',
#  'Fantasy',
#  'Historical Fiction',
#  'Fiction',
#  'Canada',
#  'Historical',
#  'Africa',
#  'African American',
#  'Adult Fiction',
#  'Book Club',
#  'Adult',
#  'Literature',
#  'Young Adult',
#  'Fiction',
#  'Contemporary',
#  'Mental Health',
#  'Romance',
#  'Audiobook',
#  'Realistic Fiction',
#  'Mental Illness',
#  'Mystery',
#  'Teen',
#  'Fantasy',
#  'Fiction',
#  'Young Adult',
#  'Plays',
#  'Magic',
#  'Adventure',
#  'Drama',
#  'Time Travel',
#  'Childrens',
#  'Middle Grade',
#  'Young Adult',
#  'Romance',
#  'Dystopia',
#  'Fantasy',
#  'Fiction',
#  'Audiobook',
#  'Science Fiction',
#  'Teen',
#  'Chick Lit',
#  'Young Adult Fantasy',
#  'Nonfiction',
#  'Memoir',
#  'Biography',
#  'Audiobook',
#  'Biography Memoir',
#  'Autobiography',
#  'Book Club',
#  'Adult',
#  'Education',
#  'Religion',
#  'Fantasy',
#  'Middle Grade',
#  'Childrens',
#  'Fiction',
#  'Mystery',
#  'Contemporary',
#  'Chick Lit',
#  'Audiobook',
#  'Adult',
#  'Thriller',
#  'Mystery Thriller',
#  'Adult Fiction',
#  'Australia',
#  'Fantasy',
#  'Young Adult',
#  'Dystopia',
#  'Romance',
#  'Fiction',
#  'Young Adult Fantasy',
#  'Audiobook',
#  'Science Fiction',
#  'Magic',
#  'High Fantasy',
#  'Thriller',
#  'Crime',
#  'Action',
#  'Police',
#  'Fiction',
#  'Mystery',
#  'Post Apocalyptic',
#  'Literary Fiction',
#  'Dystopia',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'New Adult',
#  'Magic',
#  'Young Adult Fantasy',
#  'Fiction',
#  'Fae',
#  'High Fantasy',
#  'Paranormal',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'Fiction',
#  'Magic',
#  'Young Adult Fantasy',
#  'Mystery',
#  'Audiobook',
#  'Adventure',
#  'High Fantasy',
#  'Fantasy',
#  'Fiction',
#  'Mythology',
#  'Historical Fiction',
#  'Audiobook',
#  'Retellings',
#  'Historical',
#  'Adult',
#  'Magic',
#  'Adult Fiction',
#  'Fiction',
#  'Fantasy',
#  'Epic',
#  'Drama',
#  'Novels',
#  'Young Adult',
#  'Contemporary',
#  'Adventure',
#  'Fiction',
#  'Contemporary',
#  'Epic',
#  'Novels',
#  'Drama',
#  'Fiction',
#  'Contemporary',
#  'Audiobook',
#  'Adult',
#  'Adult Fiction',
#  'Mental Health',
#  'Book Club',
#  'Novels',
#  'Literary Fiction',
#  'Chick Lit',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Magic',
#  'Young Adult Fantasy',
#  'High Fantasy',
#  'Adventure',
#  'Science Fiction Fantasy',
#  'Audiobook',
#  'Teen',
#  'Nonfiction',
#  'Memoir',
#  'Biography',
#  'Medicine',
#  'Medical',
#  'Audiobook',
#  'Biography Memoir',
#  'Autobiography',
#  'Philosophy',
#  'Science',
#  'Picture Books',
#  'Childrens',
#  'Fiction',
#  'Classics',
#  'Animals',
#  'Family',
#  'Rabbits',
#  'Kids',
#  'Love',
#  'Fantasy',
#  'Drama',
#  'Contemporary',
#  'Book Club',
#  'Thriller',
#  'Suspense',
#  'Fiction',
#  'Mystery',
#  'Epic',
#  'Novels',
#  'Dark',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Romance',
#  'Magic',
#  'Fairy Tales',
#  'High Fantasy',
#  'Adult',
#  'Retellings',
#  'New Adult',
#  'Contemporary',
#  'Epic',
#  'Fiction',
#  'Drama',
#  'Novels',
#  'Contemporary',
#  'Book Club',
#  'Drama',
#  'Epic',
#  'Fiction',
#  'Novels',
#  'Fantasy',
#  'Mythology',
#  'Young Adult',
#  'Middle Grade',
#  'Fiction',
#  'Adventure',
#  'Urban Fantasy',
#  'Magic',
#  'Childrens',
#  'Young Adult Fantasy',
#  'Epic',
#  'Contemporary',
#  'Fiction',
#  'Novels',
#  'Drama',
#  'Historical Fiction',
#  'Fiction',
#  'Romance',
#  'Contemporary',
#  'LGBT',
#  'Adult',
#  'Audiobook',
#  'Historical',
#  'Adult Fiction',
#  'Chick Lit',
#  'Drama',
#  'Mystery',
#  'Crime',
#  'Fiction',
#  'Thriller',
#  'Suspense',
#  'Psychological Thriller',
#  'Adult Fiction',
#  'Novels',
#  'Adventure',
#  'Science Fiction',
#  'Fiction',
#  'Thriller',
#  'Mystery',
#  'Audiobook',
#  'Mystery Thriller',
#  'Adult',
#  'Fantasy',
#  'Science Fiction Fantasy',
#  'Suspense',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'Retellings',
#  'Fiction',
#  'Young Adult Fantasy',
#  'Magic',
#  'Historical Fiction',
#  'Fairy Tales',
#  'Historical',
#  'Parenting',
#  'Historical Fiction',
#  'Young Adult',
#  'Historical',
#  'Fiction',
#  'World War II',
#  'War',
#  'Audiobook',
#  'Romance',
#  'Teen',
#  'Survival',
#  'Fantasy',
#  'Fiction',
#  'Epic Fantasy',
#  'High Fantasy',
#  'Audiobook',
#  'Adult',
#  'Magic',
#  'Epic',
#  'Science Fiction Fantasy',
#  'Adventure',
#  'Fantasy',
#  'Young Adult',
#  'Paranormal',
#  'LGBT',
#  'Romance',
#  'Fiction',
#  'Magic',
#  'Urban Fantasy',
#  'Audiobook',
#  'Young Adult Fantasy',
#  'Young Adult',
#  'Romance',
#  'Contemporary',
#  'Fiction',
#  'Audiobook',
#  'Chick Lit',
#  'Young Adult Contemporary',
#  'Realistic Fiction',
#  'High School',
#  'Young Adult Romance',
#  'Historical Fiction',
#  'Fiction',
#  'Historical',
#  'Audiobook',
#  'World War II',
#  'Holocaust',
#  'War',
#  'Romance',
#  'Adult',
#  'Adult Fiction',
#  'Mystery',
#  'Thriller',
#  'Fiction',
#  'Mystery Thriller',
#  'Audiobook',
#  'Suspense',
#  'Crime',
#  'Adult',
#  'Psychological Thriller',
#  'Contemporary',
#  'Historical Fiction',
#  'Fiction',
#  'Russia',
#  'Historical',
#  'Audiobook',
#  'Book Club',
#  'Literary Fiction',
#  'Novels',
#  'Adult Fiction',
#  'Adult',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'Fae',
#  'Young Adult Fantasy',
#  'Fiction',
#  'Magic',
#  'Audiobook',
#  'Fairies',
#  'Urban Fantasy',
#  'Fiction',
#  'Classics',
#  'Historical Fiction',
#  'Literature',
#  'Historical',
#  'Feminism',
#  'Literary Fiction',
#  'Novels',
#  '20th Century',
#  'School',
#  'Contemporary',
#  'Fiction',
#  'Young Adult',
#  'New Adult',
#  'Love Story',
#  'Adult',
#  'Romance',
#  'Novels',
#  'Contemporary Romance',
#  'Chick Lit',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'Fiction',
#  'Young Adult Fantasy',
#  'Audiobook',
#  'Magic',
#  'High Fantasy',
#  'Adventure',
#  'Science Fiction Fantasy',
#  'Fantasy',
#  'Fiction',
#  'Young Adult',
#  'Magic',
#  'Adult',
#  'LGBT',
#  'Romance',
#  'Audiobook',
#  'Adventure',
#  'New Adult',
#  'Young Adult',
#  'Romance',
#  'Contemporary',
#  'Fiction',
#  'Audiobook',
#  'Realistic Fiction',
#  'Young Adult Contemporary',
#  'Teen',
#  'Young Adult Romance',
#  'Family',
#  'Historical Fiction',
#  'Mystery',
#  'Fiction',
#  'Historical',
#  'World War II',
#  'War',
#  'British Literature',
#  'Historical Mystery',
#  'Audiobook',
#  'Adult',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'Urban Fantasy',
#  'Science Fiction',
#  'Young Adult Fantasy',
#  'New Adult',
#  'Paranormal',
#  'Paranormal Romance',
#  'Fiction',
#  'Epic',
#  'Contemporary',
#  'Novels',
#  'Drama',
#  'Fiction',
#  'Suspense',
#  'Fantasy',
#  'Young Adult',
#  'Retellings',
#  'Romance',
#  'Fiction',
#  'Fairy Tales',
#  'Young Adult Fantasy',
#  'Audiobook',
#  'Magic',
#  'Fairy Tale Retellings',
#  'Science Fiction',
#  'Fiction',
#  'Philosophy',
#  'Artificial Intelligence',
#  'Young Adult',
#  'Spirituality',
#  'New Adult',
#  'Dystopia',
#  'Historical Fiction',
#  'Young Adult',
#  'LGBT',
#  'Romance',
#  'Historical',
#  'Fiction',
#  'Audiobook',
#  'Queer',
#  'Fantasy',
#  'Adventure',
#  'Contemporary',
#  'Novels',
#  'Book Club',
#  'Fiction',
#  'Drama',
#  'Epic',
#  'Nonfiction',
#  'Business',
#  'Self Help',
#  'Philosophy',
#  'Leadership',
#  'Finance',
#  'Personal Development',
#  'Psychology',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Magic',
#  'Adult',
#  'LGBT',
#  'Audiobook',
#  'Romance',
#  'Adventure',
#  'High Fantasy',
#  'Nonfiction',
#  'Memoir',
#  'Race',
#  'Audiobook',
#  'History',
#  'Biography',
#  'Social Justice',
#  'Essays',
#  'Politics',
#  'African American',
#  'Thriller',
#  'Mystery',
#  'Fiction',
#  'Mystery Thriller',
#  'Suspense',
#  'Crime',
#  'Audiobook',
#  'Adult',
#  'Contemporary',
#  'Horror',
#  'Fantasy',
#  'Mythology',
#  'Young Adult',
#  'Middle Grade',
#  'Fiction',
#  'Adventure',
#  'LGBT',
#  'Urban Fantasy',
#  'Audiobook',
#  'Childrens',
#  'Romance',
#  'New Adult',
#  'Contemporary',
#  'Young Adult',
#  'Fiction',
#  'Contemporary Romance',
#  'Audiobook',
#  'Chick Lit',
#  'Adult',
#  'Drama',
#  'Fantasy',
#  'Young Adult',
#  'Romance',
#  'New Adult',
#  'Magic',
#  'Fiction',
#  'Young Adult Fantasy',
#  'High Fantasy',
#  'Fae',
#  'Paranormal',
#  'Science Fiction',
#  'Fantasy',
#  'Dystopia',
#  'Fiction',
#  'Young Adult',
#  'Audiobook',
#  'Science Fiction Fantasy',
#  'Adult',
#  'Adventure',
#  'Space',
#  'Fiction',
#  'Novels',
#  'Drama',
#  'Contemporary',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Magic',
#  'Young Adult Fantasy',
#  'Audiobook',
#  'Romance',
#  'Adventure',
#  'High Fantasy',
#  'Africa',
#  'Science Fiction',
#  'Fiction',
#  'Fantasy',
#  'Science Fiction Fantasy',
#  'Classics',
#  'Space Opera',
#  'Audiobook',
#  'Novels',
#  'Speculative Fiction',
#  'Space',
#  'Fiction',
#  'Thriller',
#  'Mystery',
#  'Espionage',
#  'Mystery Thriller',
#  'Suspense',
#  'Spy Thriller',
#  'Novels',
#  'Audiobook',
#  'Adult',
#  'Mystery',
#  'Romantic Suspense',
#  'Thriller',
#  'Crime',
#  'Fiction',
#  'Romance',
#  'Suspense',
#  'Contemporary',
#  'Mystery Thriller',
#  'Audiobook',
#  'Historical Fiction',
#  'Fiction',
#  'Audiobook',
#  'Adult',
#  'Contemporary',
#  'Music',
#  'Historical',
#  'Adult Fiction',
#  'Romance',
#  'Book Club',
#  'Mystery',
#  'Fiction',
#  'Romantic Suspense',
#  'Thriller',
#  'Romance',
#  'Suspense',
#  'Crime',
#  'Mystery Thriller',
#  'Contemporary',
#  'Audiobook',
#  'Historical Fiction',
#  'Historical',
#  'India',
#  'Fiction',
#  'Pakistan',
#  'Medicine',
#  'Medical',
#  'Inspirational',
#  'Cultural',
#  'Doctors',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Adult',
#  'New Adult',
#  'High Fantasy',
#  'Audiobook',
#  'Young Adult Fantasy',
#  'Magic',
#  'Romance',
#  'Fantasy',
#  'Historical Fiction',
#  'Fiction',
#  'Young Adult',
#  'Historical',
#  'Fairy Tales',
#  'Russia',
#  'Mythology',
#  'Adult',
#  'Audiobook',
#  'Young Adult',
#  'Contemporary',
#  'LGBT',
#  'Fiction',
#  'Romance',
#  'Audiobook',
#  'Queer',
#  'Science Fiction',
#  'Fantasy',
#  'Young Adult Contemporary',
#  'Fantasy',
#  'Young Adult',
#  'Dystopia',
#  'Romance',
#  'Fiction',
#  'Young Adult Fantasy',
#  'Audiobook',
#  'Science Fiction',
#  'Magic',
#  'High Fantasy',
#  'Psychology',
#  'Business',
#  'Nonfiction',
#  'Economics',
#  'Science',
#  'Self Help',
#  'Personal Development',
#  'Finance',
#  'Sociology',
#  'Social Science',
#  'Romance',
#  'Suspense',
#  'Contemporary Romance',
#  'Contemporary',
#  'Romantic Suspense',
#  'Erotica',
#  'Mystery',
#  'New Adult',
#  'Adult',
#  'Chick Lit',
#  'Mystery',
#  'Fiction',
#  'Thriller',
#  'Crime',
#  'Mystery Thriller',
#  'Suspense',
#  'Audiobook',
#  'Contemporary',
#  'Adult',
#  'Detective',
#  'Fantasy',
#  'Young Adult',
#  'Fiction',
#  'Paranormal',
#  'Historical Fiction',
#  'Adventure',
#  'Audiobook',
#  'Horror',
#  'Time Travel',
#  'Supernatural',
#  'Mystery',
#  'Fiction',
#  'Thriller',
#  'Crime',
#  'Audiobook',
#  'Mystery Thriller',
#  'Suspense',
#  'Adult',
#  'Detective',
#  'Contemporary',
#  'Mystery',
#  'Thriller',
#  'Fiction',
#  'Crime',
#  'Mystery Thriller',
#  'Legal Thriller',
#  'Audiobook',
#  'Suspense',
#  'Contemporary',
#  'Adult',
#  'Contemporary',
#  'Fiction',
#  'Epic',
#  'Novels',
#  'Drama',
#  'Novels',
#  'Fiction',
#  'Contemporary',
#  'Drama',
#  'Book Club',
#  'Epic',
#  'Crime',
#  'Dark',
#  'Fiction',
#  'Contemporary',
#  'Audiobook',
#  'Sports',
#  'Adult',
#  'Adult Fiction',
#  'Literary Fiction',
#  'Book Club',
#  'Sweden',
#  'Realistic Fiction',
#  'Fiction',
#  'Thriller',
#  'Mystery',
#  'Mystery Thriller',
#  'Audiobook',
#  'Suspense',
#  'Adventure',
#  'Novels',
#  'Crime',
#  'Adult',
#  'Fantasy',
#  'Romance',
#  'LGBT',
#  'M M Romance',
#  'Adult',
#  'Fiction',
#  'Queer',
#  'Historical',
#  'New Adult',
#  'High Fantasy',
#  'Drama',
#  'Fiction',
#  'Novels',
#  'Contemporary',
#  'Novels',
#  'Fiction',
#  'Young Adult',
#  'Historical Fiction',
#  'New Adult',
#  'Historical',
#  'Adult',
#  'Middle Grade',
#  'Romance',
#  'Adventure',
#  'Young Adult',
#  'LGBT',
#  'Contemporary',
#  'Science Fiction',
#  'Fiction',
#  'Mental Health',
#  'Romance',
#  'Queer',
#  'Fantasy',
#  'Mental Illness',
#  'Epic',
#  'Contemporary',
#  'Contemporary',
#  'Novels',
#  'Fiction',
#  'Epic',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Fiction',
#  'Suspense',
#  'Romance',
#  'Romantic Suspense',
#  'Crime',
#  'Mystery Thriller',
#  'Audiobook',
#  'Contemporary',
#  'Nonfiction',
#  'Memoir',
#  'Biography',
#  'Audiobook',
#  'Humor',
#  'Autobiography',
#  'Africa',
#  ...]

# %%
unique_genre_list = []
for x in flatten_list:
    if x not in unique_genre_list:
        unique_genre_list.append(x)

unique_genre_list
# Out:
# ['Young Adult',
#  'Contemporary',
#  'LGBT',
#  'Romance',
#  'Fiction',
#  'Audiobook',
#  'Queer',
#  'Realistic Fiction',
#  'Coming Of Age',
#  'Young Adult Contemporary',
#  'Historical Fiction',
#  'Christian Fiction',
#  'Classics',
#  'Christian',
#  'Historical',
#  'Adult',
#  'Inspirational',
#  'Fantasy',
#  'New Adult',
#  'Fae',
#  'Magic',
#  'Young Adult Fantasy',
#  'High Fantasy',
#  'Paranormal',
#  'Gay',
#  'M M Romance',
#  'Literature',
#  'Novels',
#  'American',
#  'Literary Fiction',
#  'Science Fiction',
#  '20th Century',
#  'School',
#  'Book Club',
#  'True Story',
#  'Drama',
#  'Abuse',
#  'Adult Fiction',
#  'Adventure',
#  'Science Fiction Fantasy',
#  'Urban Fantasy',
#  'Teen',
#  'Young Adult Romance',
#  'Retellings',
#  'Dystopia',
#  'Fairy Tales',
#  'Contemporary Romance',
#  'Disability',
#  'Erotica',
#  'Angels',
#  'Vampires',
#  'Epic',
#  'Poetry',
#  'Philosophy',
#  'Portugal',
#  'Portuguese Literature',
#  'Unfinished',
#  'Mystery',
#  'Love Story',
#  'Space',
#  'Thriller',
#  'Chick Lit',
#  'Picture Books',
#  'Childrens',
#  'Animals',
#  'Humor',
#  'Kids',
#  'Food',
#  'Storytime',
#  'Time Travel',
#  'Horror',
#  'Supernatural',
#  'College',
#  'High School',
#  'Canada',
#  'Africa',
#  'African American',
#  'Mental Health',
#  'Mental Illness',
#  'Plays',
#  'Middle Grade',
#  'Nonfiction',
#  'Memoir',
#  'Biography',
#  'Biography Memoir',
#  'Autobiography',
#  'Education',
#  'Religion',
#  'Mystery Thriller',
#  'Australia',
#  'Crime',
#  'Action',
#  'Police',
#  'Post Apocalyptic',
#  'Mythology',
#  'Medicine',
#  'Medical',
#  'Science',
#  'Family',
#  'Rabbits',
#  'Love',
#  'Suspense',
#  'Dark',
#  'Psychological Thriller',
#  'Parenting',
#  'World War II',
#  'War',
#  'Survival',
#  'Epic Fantasy',
#  'Holocaust',
#  'Russia',
#  'Fairies',
#  'Feminism',
#  'British Literature',
#  'Historical Mystery',
#  'Paranormal Romance',
#  'Fairy Tale Retellings',
#  'Artificial Intelligence',
#  'Spirituality',
#  'Business',
#  'Self Help',
#  'Leadership',
#  'Finance',
#  'Personal Development',
#  'Psychology',
#  'Race',
#  'History',
#  'Social Justice',
#  'Essays',
#  'Politics',
#  'Space Opera',
#  'Speculative Fiction',
#  'Espionage',
#  'Spy Thriller',
#  'Romantic Suspense',
#  'Music',
#  'India',
#  'Pakistan',
#  'Cultural',
#  'Doctors',
#  'Economics',
#  'Sociology',
#  'Social Science',
#  'Detective',
#  'Legal Thriller',
#  'Sports',
#  'Sweden',
#  'South Africa',
#  'Pirates',
#  'Technology',
#  'Entrepreneurship',
#  'Magical Realism',
#  'Spanish Literature',
#  'Spain',
#  'Womens',
#  'BDSM',
#  'Erotic Romance',
#  'Clean Romance',
#  'Womens Fiction',
#  'Adoption',
#  'Novella',
#  'Short Stories',
#  'Italy',
#  'Relationships',
#  'New York',
#  'Cult Classics',
#  'German Literature',
#  'Modern',
#  '21st Century',
#  'Historical Romance',
#  'Ireland',
#  'Superheroes',
#  'Russian Literature',
#  'Demons',
#  'Gods',
#  'France',
#  'World War I',
#  'Witches',
#  'Theatre',
#  'Tragedy',
#  'Society',
#  'Money',
#  'Ghana',
#  'Health',
#  'Health Care',
#  'Asia',
#  'Irish Literature',
#  'French Literature',
#  '19th Century',
#  'Americana',
#  'The United States Of America',
#  'Elves',
#  'Juvenile',
#  'Romantic',
#  'Westerns',
#  'Dragons',
#  'Boarding School',
#  'Amazon',
#  'Comedy',
#  'China',
#  'Transgender',
#  'Physics',
#  'Astronomy',
#  'Popular Science',
#  'Death',
#  'Hockey',
#  'Indian Literature',
#  'Gaming',
#  'Games',
#  'Nature',
#  'Environment',
#  'Aliens',
#  'Greek Mythology',
#  'Writing',
#  'Art',
#  'Military Fiction',
#  'Murder Mystery',
#  'Steampunk',
#  'Books About Books',
#  'Anthologies',
#  'Apocalyptic',
#  'Ancient History',
#  'Roman',
#  'Germany',
#  'Poland',
#  'Teaching',
#  'Zombies',
#  'True Crime',
#  'American History',
#  'Japan',
#  'Cats',
#  'Japanese Literature',
#  'Graphic Novels',
#  'Comics',
#  'Graphic Novels Comics',
#  'Nigeria',
#  'Buddhism',
#  'Eastern Philosophy',
#  'Cyberpunk',
#  'Alternate History',
#  'Fantasy Romance',
#  'Cinderella',
#  'Illness',
#  'Swedish Literature',
#  'Law',
#  '18th Century',
#  'Asian Literature',
#  'New Adult Romance',
#  'Mermaids',
#  'Lesbian',
#  'Young Adult Science Fiction',
#  'Beauty and The Beast',
#  'New Age',
#  'Motorcycle',
#  'Gender',
#  'Christmas',
#  'Holiday',
#  'Cameroon',
#  'Musicians',
#  'Medieval',
#  'Robots',
#  'Ghosts',
#  'Biology',
#  'Cozy Mystery',
#  'Southern',
#  'Regency',
#  'Christian Fantasy',
#  'Sports Romance',
#  'Noir',
#  'Productivity',
#  'Travel',
#  'Journalism',
#  'Futuristic',
#  'Gothic',
#  'Shapeshifters',
#  'Werewolves',
#  'Dogs',
#  'Management',
#  'Neuroscience',
#  'Comic Book',
#  'Poverty',
#  'Social Issues',
#  'Victorian',
#  'Italian Literature',
#  'Batman',
#  'Dc Comics',
#  'Fighters',
#  'Mixed Martial Arts',
#  'Buisness',
#  'Terrorism',
#  'Logic',
#  'Amish',
#  'Photography',
#  'Young Adult Historical Fiction',
#  'Historical Fantasy',
#  'Manga',
#  'Shonen',
#  'American Fiction',
#  'Seinen',
#  'Slice Of Life',
#  'Science Fiction Romance',
#  'M M Fantasy',
#  'Pop Culture',
#  'Anti Racist',
#  'Scotland',
#  'Algeria',
#  'Christian Romance',
#  'Chapter Books',
#  'Anthropology',
#  'Hackers',
#  'Baseball',
#  'Road Trip',
#  'Dark Fantasy',
#  'Horses',
#  'Pre K',
#  'Christianity',
#  'Reference',
#  'Theology',
#  'Church History',
#  'Climate Change Fiction',
#  'Harlequin Heartwarming',
#  'Harlequin',
#  'Lesbian Fiction',
#  'Asexual',
#  'Marriage',
#  'Jewish',
#  'Communication',
#  'Polish Literature',
#  'Nobel Prize',
#  'Art History',
#  'Light Novel',
#  'Indonesian Literature',
#  'Turkish Literature',
#  'Turkish',
#  'Metaphysics',
#  'Finnish Literature',
#  'Presidents',
#  'Vegan',
#  'Wolves',
#  'M F Romance',
#  'Collections',
#  'Political Science',
#  'Faith',
#  'Church',
#  'Cooking',
#  'Poetry Plays',
#  'Weird Fiction',
#  'New Weird',
#  'Lovecraftian',
#  'Short Story Collection',
#  'Surreal',
#  'Ecology',
#  'Plants',
#  'Natural History',
#  'Science Nature',
#  'Military Romance',
#  'Heroic Fantasy',
#  'International',
#  'Christian Historical Fiction',
#  'American Revolutionary War',
#  'Dinosaurs',
#  'Genderqueer',
#  'Intersex',
#  'Anime',
#  'Urban',
#  'Star Wars',
#  'Film',
#  'Marvel',
#  'Folklore',
#  'How To',
#  'Christian Living',
#  'Christian Non Fiction',
#  'God',
#  'Young Readers',
#  'Regency Romance',
#  'Football',
#  'Animal Fiction',
#  'Counselling',
#  'Psychiatry',
#  'Psychoanalysis',
#  'Prayer',
#  'Astrology',
#  'Students',
#  'Egypt',
#  'M F M',
#  'Gay Erotica',
#  'Foodie',
#  'Virtual Reality',
#  'Conservation',
#  'Martial Arts',
#  'Own',
#  'Media Tie In',
#  'African American Literature',
#  'M M Sports Romance',
#  'Lds Fiction',
#  'Lds',
#  'Lesbian Romance',
#  'World History',
#  'Tanzania',
#  'Sexuality',
#  'Cookbooks',
#  'Halloween',
#  'Computer Science',
#  'Programming',
#  'Comix',
#  'Theory',
#  'Academic',
#  'Literary Criticism',
#  'Warcraft',
#  'World Of Warcraft',
#  'Video Games',
#  'International Relations',
#  'Military History',
#  'Reverse Harem',
#  'Omegaverse',
#  'Computers',
#  'Diary',
#  'Fashion',
#  'Menage',
#  'Gay For You',
#  'Military Science Fiction',
#  'Biblical Fiction',
#  '16th Century',
#  'Scandinavian Literature',
#  'Mathematics',
#  'Language',
#  'Criticism',
#  'Islam',
#  'Apple',
#  'Tea',
#  'Geography',
#  'Comics Manga',
#  'Female Authors',
#  'Chinese Literature',
#  'Czech Literature',
#  'European Literature',
#  'Hard Science Fiction',
#  'Occult',
#  'Evolution',
#  'Dungeons and Dragons',
#  'Princesses',
#  'Divorce',
#  'Josei',
#  'Harem',
#  'Sword and Sorcery',
#  'Anthropomorphic',
#  'Civil War',
#  'Role Playing Games',
#  'Futurism',
#  'Tv',
#  'Linguistics',
#  'Yuri',
#  'Monsters',
#  'Quantum Mechanics',
#  'M M M',
#  'Human Development',
#  'Ghost Stories',
#  'Fostering',
#  '17th Century',
#  'Yaoi',
#  'Boys Love',
#  'Star Trek',
#  'Genetics',
#  'Birds',
#  'English Literature',
#  'Emotion',
#  '1st Grade',
#  'African Literature',
#  'Catholic',
#  'Israel',
#  'Firefighters',
#  'M M Contemporary',
#  'Western Romance',
#  'History Of Science',
#  'Bisexual',
#  'Gardening',
#  'Punk',
#  'Butch Femme',
#  'Rwanda',
#  'Shojo',
#  'Scripture',
#  'Judaism',
#  'Comic Fantasy',
#  'X Men',
#  'American Civil War',
#  'Graphic Novels Manga',
#  'Biblical',
#  'Arthurian',
#  'Conspiracy Theories',
#  'Government',
#  'Sustainability',
#  'Musicals',
#  'European History',
#  'Ancient',
#  'Japanese History',
#  'Comic Strips',
#  'Queer Lit',
#  'Hinduism',
#  'Spider Man',
#  'Food and Drink',
#  'Cults',
#  'Walking',
#  'Polyamory',
#  'Rock N Roll',
#  'Womens Studies',
#  'Nutrition',
#  'Diets',
#  'Soviet Union',
#  'Webcomic',
#  'Research',
#  'Activism',
#  'Greece',
#  'Professors',
#  'Teachers',
#  'Gamebooks',
#  'Young Adult Paranormal',
#  'Journal',
#  'Crafts',
#  'Geek',
#  'Class',
#  'School Stories',
#  'Nerd',
#  'Superman',
#  'Fandom',
#  'Native Americans',
#  'Latin American',
#  'Lie',
#  'Sequential Art',
#  'Growth Mindset',
#  'Time Travel Romance',
#  'Canadian Literature',
#  'Colouring Books',
#  'Iran',
#  'Graphic Novels Comics Manga',
#  'Food Writing',
#  'Latin American Literature',
#  'Bande Dessinée',
#  'Georgian',
#  'Naval History',
#  'Wonder Woman',
#  'Vaccines',
#  'Brazil',
#  'Soccer',
#  'Brain',
#  'Bizarro Fiction',
#  'M M Mystery',
#  'Counting',
#  'Number',
#  'Denmark',
#  'Geology',
#  'International Development',
#  'Old Testament',
#  'M M Historical Romance',
#  'Guides',
#  'Us Presidents',
#  'Warriors',
#  'Soldiers',
#  'Microhistory',
#  'Outdoors',
#  'Paranormal Urban Fantasy',
#  'Climate Change']

# %%
# check the lengths of the two lists to make sure it worked 
print(len(flatten_list))
print(len(unique_genre_list))
# Out:
# 33829
# 561

# %%
#create a table of the unique genre values
genre_table = pd.DataFrame(unique_genre_list, columns = ['genre'])
genre_table
# Out:
#                         genre
# 0                 Young Adult
# 1                Contemporary
# 2                        LGBT
# 3                     Romance
# 4                     Fiction
# ..                        ...
# 556                  Soldiers
# 557              Microhistory
# 558                  Outdoors
# 559  Paranormal Urban Fantasy
# 560            Climate Change
#
# [561 rows x 1 columns]

# %%
# Add a Primary Key to each genre
genre_table['genre_id'] = genre_table.index + 500
genre_table
# Out:
#                         genre  genre_id
# 0                 Young Adult       500
# 1                Contemporary       501
# 2                        LGBT       502
# 3                     Romance       503
# 4                     Fiction       504
# ..                        ...       ...
# 556                  Soldiers      1056
# 557              Microhistory      1057
# 558                  Outdoors      1058
# 559  Paranormal Urban Fantasy      1059
# 560            Climate Change      1060
#
# [561 rows x 2 columns]
